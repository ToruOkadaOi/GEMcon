# %%
import requests
from bs4 import BeautifulSoup

def scrape():
    
    url = 'https://pax-db.org/species/9606'
    response = requests.get(url)#.json()
    soup = BeautifulSoup(response.text, 'html.parser')
    print(soup)

if __name__ == '__main__':
    scrape()
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><title>PaxDb: Protein Abundance Database</title><meta charset="utf-8"/><meta content="PaxDb: Protein Abundance Database" name="description"/><meta content="telephone=no" name="format-detection"/><meta content="no" name="msapplication-tap-highlight"/><meta content="initial-scale=1,width=device-width,viewport-fit=cover" name="viewport"/><link href="statics/paxdb_logo.png" rel="icon" type="image/x-icon"/><link href="statics/icons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="statics/icons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-TH4S5Z78JN"></script><script>window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin


def get_paxdb_9606_links():
    base = "https://pax-db.org"
    listing_url = f"{base}/downloads/3.0/datasets/9606/"

    r = requests.get(listing_url)
    r.raise_for_status()

    soup = BeautifulSoup(r.text, "html.parser")

    links = []
    for a in soup.find_all("a", href=True):
        href = a["href"]
        if href.endswith(".txt"):
            links.append(urljoin(listing_url, href))

    return links


if __name__ == "__main__":
    for url in get_paxdb_9606_links():
        print(url)
# Out:
# https://pax-db.org/downloads/3.0/datasets/9606/9606-A431_cellline_Lundberg_2010.txt
# https://pax-db.org/downloads/3.0/datasets/9606/9606-A549_Geiger_2012.txt
# https://pax-db.org/downloads/3.0/datasets/9606/9606-Adult_Adrenalgland_Kim_2014_SEQUEST.txt
# https://pax-db.org/downloads/3.0/datasets/9606/9606-Adult_Bcells_Kim_2014_SEQUEST.txt
# https://pax-db.org/downloads/3.0/datasets/9606/9606-Adult_CD4Tcells_Kim_2014_SEQUEST.txt
# https://pax-db.org/downloads/3.0/datasets/9606/9606-Adult_CD8Tcells_Kim_2014_SEQUEST.txt
# https://pax-db.org/downloads/3.0/datasets/9606/9606-Adult_Colon_Kim_2014_SEQUEST.txt
# https://pax-db.org/downloads/3.0/datasets/9606/9606-Adult_Esophagus_Kim_2014_SEQUEST.txt
# https://pax-db.org/downloads/3.0/datasets/9606/9606-Adult_Frontalcortex_Kim_2014_SEQUEST.txt
# https://pax-db.org/downloads/3.0/datasets/9606/9606-Adult_Gallbladder_Kim_2014_SEQUEST.txt
# https://pax-db.org/downloads/3.0/datasets/9606/9606-Adult_Heart_Kim_2014_SEQUEST.txt
# ...

# %%
## save locally # postgre docker - persistent volume
