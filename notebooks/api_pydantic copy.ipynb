# %%
from pydantic import BaseModel, Field
from typing import List, Optional

# %%
import requests
from requests.exceptions import HTTPError
import json, time

import aiohttp
import asyncio
from aiohttp import ClientTimeout

# %%
import pandas as pd

# %%
class File(BaseModel):
    name: str
    format: Optional[str] = None # Maybe not optional??
    url: Optional[str] = None

# %%
class Project(BaseModel):
    projectTitle: Optional[List[Optional[str]]] = None
    laboratory: Optional[List[Optional[str]]] = None

# %%
class Sample(BaseModel):
    organ: Optional[List[Optional[str]]] = None
    disease: Optional[List[Optional[str]]] = None

# %%
class Hit(BaseModel):
    projects: List[Project]
    samples: Optional[List[Sample]] = None
    files: List[File]

# %%
filters = {
    "genusSpecies": {"is": ["Homo sapiens"]},
    "fileSource": {"is": ["DCP/2 Analysis"]},
    "fileFormat": {"is": ["loom"]},
    "isIntermediate": {"is": [False]} # hvy filter
}

# %%
size=100
catalog = "dcp54"

base_url = "https://service.azul.data.humancellatlas.org/index/files"

def fetch_all_pages(catalog=catalog, filters=filters, size=50):
    params = {"catalog": catalog, "filters": json.dumps(filters), "size": size}
    hits, url, page = [], base_url, 1 # empty list to store evrytg

    while url:
        print(f"page {page}")
        r = requests.get(url, params=params if url == base_url else None)
        # stat at this point
        if r.status_code != 200:
            print("error", r.status_code, r.text[:200])
            break

        data = r.json()
        if page == 1:
            facets = data.get("termFacets")
        hits += data.get("hits", [])
        url = data.get("pagination", {}).get("next")
        params = None
        page += 1

        time.sleep(0.2)

    return hits, facets

raw_hits, facets = fetch_all_pages()
hits = [Hit(**h) for h in raw_hits]
print("validated:", len(hits))
# Out:
# page 1
# page 2
# page 3
# validated: 101

# %%
formats = facets["fileFormat"]["terms"]
pd.DataFrame(formats)
# Out:
#         term   count
# 0   fastq.gz  155749
# 1        bam   36553
# 2        bai   35573
# 3      fastq   16637
# 4     tsv.gz    4044
# ..       ...     ...
# 78  h5ad.zip       1
# 79       md5       1
# 80    son.gz       1
# 81    tab.gz       1
# 82    zip.gz       1
#
# [83 rows x 2 columns]

# %%
# df = pd.DataFrame(formats)
# fastq_df = df[df["term"].isin(["fastq.gz", "fastq"])]

# %%
# think of use for termfacets

# %%
rows = []
for hit in hits:
    for project in hit.projects or []:
        project_title = ", ".join(project.projectTitle or [])
        labs = project.laboratory or []
        lab_names = "; ".join(str(lab) for lab in labs if lab) or "N/A"

        # samples = hit.samples or []

        # if samples:
        #         organ = ", ".join(samples[0].organ or ["N/A"])
        #         disease = ", ".join(samples[0].disease or ["N/A"])
        # else:
        #         organ = "N/A"
        #         disease = "N/A"

for file in hit.files or []:
        # print(
        #     f"Project: {project_title}\n"
        #     f"Project lab: {lab_names}\n"
        #     #f"Organ: {organ}\n"
        #     #f"Disease: {disease}\n"
        #     f"File: {file.name}\n"
        #     f"URL: {file.url}\n"
        # )
        rows.append({
                "Project": project_title,
                "Project lab": lab_names,
                #"Organ": organ,
               #"Disease": disease,
                "File": file.name,
                "URL": file.url})
        
df =pd.DataFrame(rows)
df
# Out:
#                                                                                        Project  \
# 0  Single-cell transcriptomics reveals unique features of human pancreatic islet cell subtypes
#
#                                   Project lab  \
# 0  Human Cell Atlas Data Coordinaton Platform
#
#                                                File  \
# 0  unique-pancreatic-islets-human-pancreas-SS2.loom
#
#                                                                                                                                                         URL
# 0  https://service.azul.data.humancellatlas.org/repository/files/733c22aa-6f5a-5055-a147-000e4474b5ab?catalog=dcp54&version=2022-01-19T16%3A16%3A27.000000Z

# %%
rows = []

for hit in hits:
    for project in hit.projects or []:
        project_title = ", ".join(project.projectTitle or [])
        lab_names = "; ".join([lab for lab in (project.laboratory or []) if lab]) or "N/A"
        
        for file in hit.files or []:
            rows.append({
                "Project": project_title,
                "Project lab": lab_names,
                "File": file.name,
                "Url": file.url
            })

df = pd.DataFrame(rows)
df
# Out:
#                                                                                                                                                                    Project  \
# 0                                                                                                Re-evaluation of human BDCA-2+ DC during acute sterile skin inflammation.
# 1                                                                                                Re-evaluation of human BDCA-2+ DC during acute sterile skin inflammation.
# 2                                                                               Dissecting the clonal nature of allelic expression in somatic cells by single-cell RNA-seq
# 3                                                                                                                        Single cell RNA sequencing of multiple myeloma II
# 4                                                                        Precursors of human CD4+ cytotoxic T lymphocytes identified by single-cell transcriptome analysis
# 5                                                                                         Cryopreservation and post-thaw characterization of dissociated human islet cells
# 6                                                                                                          Single-cell RNA-seq reveals heterogeneity within human pre-cDCs
# 7                                                       Single cell analysis of human fetal liver captures the transcriptional profile of hepatobiliary hybrid progenitors
# 8                                                                                                              Single-Cell Transcriptomics of the Human Endocrine Pancreas
# 9                                                                                                  Single cell RNA-sequencing of human tonsil Innate lymphoid cells (ILCs)
# 10                                                       Single-Cell RNAseq analysis of diffuse neoplastic infiltrating cells at the migrating front of human glioblastoma
# 11                                                            Single-cell omics reveal human mononuclear phagocyte heterogeneity and inflammatory DC in health and disease
# 12                                                                                     Single-cell analysis reveals the continuum of human lympho-myeloid progenitor cells
# 13                                                                   Single cell sequencing identifies novel sub-populations of breast cancer cells selected under hypoxia
# 14                                               Spatial and single-cell transcriptional profiling identifies functionally distinct human dermal fibroblast subpopulations
# 15                                                                     Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics
# 16                                                                     Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics
# 17                                                                            Single-Cell Transcriptome Profiling of Human Pancreatic Islets in Health and Type 2 Diabetes
# 18  Single-cell RNA-seq analysis  throughout a 125-day differentiation protocol that converted H1 human embryonic stem cells to a variety of ventrally-derived cell types.
# 19                                                                                                                 Distinct microbial and immune niches of the human colon
# 20                                                                                                                 Distinct microbial and immune niches of the human colon
# 21                                                                             Tracing pluripotency of human early embryos and embryonic stem cells by single cell RNA-seq
# 22                                                                             Tracing pluripotency of human early embryos and embryonic stem cells by single cell RNA-seq
# 23                                                                                          Transcriptomes of 1,529 individual cells from 88 human preimplantation embryos
# 24                                                        Single-Cell Analysis of Human Pancreas Reveals Transcriptional Signatures of Aging and Somatic Mutation Patterns
# 25                                                            Single-cell transcriptomics uncovers distinct molecular signatures of stem cells in chronic myeloid leukemia
# 26                                                                                                   Systematic comparative analysis of single cell RNA-sequencing methods
# 27                                                                             Single-cell transcriptomics reveals unique features of human pancreatic islet cell subtypes
#
#                                                                                                                                                                                                                                                                                                                                                                    Project lab  \
# 0                                                                                                                                                                                                         Centre for Computational Biology; Department of Plastic and Reconstructive Surgery; Medical Research Council Human Immunology Unit, Radcliffe Department of Medicine
                                                                                                                                                                                                                                                                                 Human Cell Atlas Data Coordination Platform; MRC Molecular Haematology Unit
# 26                                                                                                                                                                                                                                                                Human Cell Atlas Data Coordination Platform; Klarman Cell Observatory; McGovern Institute for Brain Research
# 27                                                                                                                                                                                                                                                                                                                                  Human Cell Atlas Data Coordinaton Platform
#
#                                                                  File  \
# 0                          AcuteSkinInflammation-human-blood-SS2.loom
# 1                           AcuteSkinInflammation-human-skin-SS2.loom
# 2              AllelicExpressionPatterns-human-hematopoeitic-SS2.loom
# 3                    Bone-Marrow-Myeloma-human-hematopoeitic-SS2.loom
# 4                                  CD4-cytotoxic-human-blood-SS2.loom
# 5                              CryoPancreatic-human-pancreas-SS2.loom
# 6                           HumanDCsFromPre-cDCs-human-blood-SS2.loom
# 7                      HumanDevoLiverSegalRashid-human-liver-SS2.loom
# 8                      HumanEndocrinePancreas-human-pancreas-SS2.loom
# 9                    HumanInnateLymphoidCells-human-pancreas-SS2.loom
# 10  InfiltratingNeoplasticCellsHumanGlioblastoma-human-brain-SS2.loom
# 11                                 Lupus-Dutetre-human-blood-SS2.loom
# 12                             Lymphomyeloid-human-umbilical-SS2.loom
# 13                         THP1StimulationCells-human-breast-SS2.loom
# 14                           dermal-fibroblast-human-abdomen-SS2.loom
# 15                                fetal-maternal-human-blood-SS2.loom
# 16                              fetal-maternal-human-decidua-SS2.loom
# 17                           healthy-diabetes-human-pancreas-SS2.loom
# 18                  interneuron-differentiation-human-embryo-SS2.loom
# 19                                       niches-human-immune-SS2.loom
# 20                                    niches-human-intestine-SS2.loom
# 21                     preimplantation-ESCs-human-blastocyst-SS2.loom
# 22                         preimplantation-ESCs-human-embryo-SS2.loom
# 23                preimplantation-transcriptome-human-embryo-SS2.loom
# 24                           sc-aging-somatic-human-pancreas-SS2.loom
# 25                    stem-cells-myeloid-human-hematopoeitic-SS2.loom
# 26                         systematic-comparison-human-blood-SS2.loom
# 27                   unique-pancreatic-islets-human-pancreas-SS2.loom
#
#                                                                                                                                                          Url
# 0   https://service.azul.data.humancellatlas.org/repository/files/feb5f419-da5c-58ac-b866-d5f1fa9e0548?catalog=dcp54&version=2022-01-20T20%3A13%3A43.000000Z
# 1   https://service.azul.data.humancellatlas.org/repository/files/e17ad464-787e-5526-8b5d-f2fcea28cb06?catalog=dcp54&version=2022-01-19T14%3A08%3A08.000000Z
# 2   https://service.azul.data.humancellatlas.org/repository/files/d0e303fb-b679-5968-b814-1ad6c1e6db28?catalog=dcp54&version=2022-01-08T18%3A21%3A57.000000Z
# 3   https://service.azul.data.humancellatlas.org/repository/files/3014ec47-1399-57ca-ab74-c8c296232b9e?catalog=dcp54&version=2021-10-14T20%3A19%3A06.000000Z
# 4   https://service.azul.data.humancellatlas.org/repository/files/ec0ad12e-9828-54a5-86bf-58a9dbb1e679?catalog=dcp54&version=2021-10-13T03%3A43%3A25.000000Z
# 5   https://service.azul.data.humancellatlas.org/repository/files/2dc04008-2d62-5c3f-a6f1-c7cae7ac1009?catalog=dcp54&version=2022-01-08T16%3A18%3A42.000000Z
# 6   https://service.azul.data.humancellatlas.org/repository/files/43104b26-6f1f-5b14-8f6e-458d5ab05ea4?catalog=dcp54&version=2022-01-19T06%3A05%3A54.000000Z
# 7   https://service.azul.data.humancellatlas.org/repository/files/52608937-5b23-5037-8d0e-8f00696e8bcb?catalog=dcp54&version=2022-01-11T18%3A39%3A29.000000Z
# 26  https://service.azul.data.humancellatlas.org/repository/files/8464fdc4-9927-56d7-a244-08a4a0de16c9?catalog=dcp54&version=2021-11-09T21%3A28%3A56.000000Z
# 27  https://service.azul.data.humancellatlas.org/repository/files/733c22aa-6f5a-5055-a147-000e4474b5ab?catalog=dcp54&version=2022-01-19T16%3A16%3A27.000000Z

# %%
# accounting for multiple samples in hits

rows = []
for hit in hits:
    for project in hit.projects or []:
        project_title = ", ".join(project.projectTitle or [])
        labs = project.laboratory or []
        lab_names = "; ".join(str(lab) for lab in labs if lab) or "N/A"

        # collect all organs/diseases across samples
        samples = hit.samples or []
        if samples:
            organs = set()
            diseases = set()
            for s in samples:
                if getattr(s, "organ", None):
                    organs.update([str(o) for o in s.organ if o])
                if getattr(s, "disease", None):
                    diseases.update([str(d) for d in s.disease if d])
            organ = ", ".join(organs) if organs else "N/A"
            disease = ", ".join(diseases) if diseases else "N/A"
        else:
            organ = "N/A"
            disease = "N/A"

# Sasb4; in future add other metadata here
        for file in hit.files or []:
            rows.append({
                "Project": project_title,
                "Project lab": lab_names,
                "Organ": organ,
                "Disease": disease,
                "File": file.name,
                "Url": file.url
            })

df = pd.DataFrame(rows)
df
# Out:
#                                                                                                                                                                    Project  \
# 0                                                                                                Re-evaluation of human BDCA-2+ DC during acute sterile skin inflammation.
# 1                                                                                                Re-evaluation of human BDCA-2+ DC during acute sterile skin inflammation.
# 2                                                                               Dissecting the clonal nature of allelic expression in somatic cells by single-cell RNA-seq
# 3                                                                                                                        Single cell RNA sequencing of multiple myeloma II
# 4                                                                        Precursors of human CD4+ cytotoxic T lymphocytes identified by single-cell transcriptome analysis
# 5                                                                                         Cryopreservation and post-thaw characterization of dissociated human islet cells
# 6                                                                                                          Single-cell RNA-seq reveals heterogeneity within human pre-cDCs
# 7                                                       Single cell analysis of human fetal liver captures the transcriptional profile of hepatobiliary hybrid progenitors
# 8                                                                                                              Single-Cell Transcriptomics of the Human Endocrine Pancreas
# 9                                                                                                  Single cell RNA-sequencing of human tonsil Innate lymphoid cells (ILCs)
# 10                                                       Single-Cell RNAseq analysis of diffuse neoplastic infiltrating cells at the migrating front of human glioblastoma
# 11                                                            Single-cell omics reveal human mononuclear phagocyte heterogeneity and inflammatory DC in health and disease
# 12                                                                                     Single-cell analysis reveals the continuum of human lympho-myeloid progenitor cells
# 13                                                                   Single cell sequencing identifies novel sub-populations of breast cancer cells selected under hypoxia
# 14                                               Spatial and single-cell transcriptional profiling identifies functionally distinct human dermal fibroblast subpopulations
# 15                                                                     Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics
# 16                                                                     Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics
# 17                                                                            Single-Cell Transcriptome Profiling of Human Pancreatic Islets in Health and Type 2 Diabetes
# 18  Single-cell RNA-seq analysis  throughout a 125-day differentiation protocol that converted H1 human embryonic stem cells to a variety of ventrally-derived cell types.
# 19                                                                                                                 Distinct microbial and immune niches of the human colon
# 20                                                                                                                 Distinct microbial and immune niches of the human colon
# 21                                                                             Tracing pluripotency of human early embryos and embryonic stem cells by single cell RNA-seq
# 22                                                                             Tracing pluripotency of human early embryos and embryonic stem cells by single cell RNA-seq
# 23                                                                                          Transcriptomes of 1,529 individual cells from 88 human preimplantation embryos
# 24                                                        Single-Cell Analysis of Human Pancreas Reveals Transcriptional Signatures of Aging and Somatic Mutation Patterns
                                                                                                                                                                                                                                                                                 Human Cell Atlas Data Coordination Platform
# 22                                                                                                                                                                                                                                                                                                                                 Human Cell Atlas Data Coordination Platform
# 23                                                                                                                                                                                Department of Cell and Molecular Biology; Department of Clinical Science, Intervention and Technology; Department of Genetics and Evolutionary Biology; University of California, Santa Cruz
# 24                                                                                                                                                                                                                                                                                                                Human Cell Atlas Data Coordination Platform; Molecular Atlas
# 25                                                                                                                                                                                                                                                                                                 Human Cell Atlas Data Coordination Platform; MRC Molecular Haematology Unit
# 26                                                                                                                                                                                                                                                                Human Cell Atlas Data Coordination Platform; Klarman Cell Observatory; McGovern Institute for Brain Research
# 27                                                                                                                                                                                                                                                                                                                                  Human Cell Atlas Data Coordinaton Platform
#
#                    Organ  \
# 0                  blood
# 1           skin of body
# 2   hematopoietic system
# 3   hematopoietic system
# 4                  blood
# 5               pancreas
# 6                  blood
# 7                  liver
# 8               pancreas
# 9                 tonsil
# 10                 brain
# 11                 blood
# 12        umbilical cord
# 13                   N/A
# 14               abdomen
# 15                 blood
# 16               decidua
# 17              pancreas
# 18                   N/A
# 19          immune organ
# 20       large intestine
# 21            blastocyst
# 22                embryo
# 23                embryo
# 24              pancreas
# 25  hematopoietic system
# 26                 blood
# 27              pancreas
#
#                                                        Disease  \
# 0                                                       normal
# 1                                                       normal
# 2                                                       normal
# 3                                          plasma cell myeloma
# 4                                                          N/A
# 5                                                       normal
# 6                                                          N/A
# 7                                                       normal
# 8   normal, type 2 diabetes mellitus, type 1 diabetes mellitus
# 9                                                       normal
# 10                                      glioblastoma (disease)
# 11                                                      normal
# 12                                                      normal
# 13                                                         N/A
# 14                                                      normal
# 15                                                      normal
# 16                                                      normal
# 17                                                         N/A
# 18                                                         N/A
# 19                                                      normal
# 20                                                      normal
# 21                                                      normal
# 22                                                      normal
# 23                                                      normal
# 24                                                      normal
# 25                   atypical chronic myeloid leukemia, normal
# 26                                                      normal
# 27                                                      normal
#
#                                                                  File  \
# 0                          AcuteSkinInflammation-human-blood-SS2.loom
# 1                           AcuteSkinInflammation-human-skin-SS2.loom
# 2              AllelicExpressionPatterns-human-hematopoeitic-SS2.loom
# 3                    Bone-Marrow-Myeloma-human-hematopoeitic-SS2.loom
# 4                                  CD4-cytotoxic-human-blood-SS2.loom
# 5                              CryoPancreatic-human-pancreas-SS2.loom
# 6                           HumanDCsFromPre-cDCs-human-blood-SS2.loom
# 7                      HumanDevoLiverSegalRashid-human-liver-SS2.loom
# 8                      HumanEndocrinePancreas-human-pancreas-SS2.loom
# 9                    HumanInnateLymphoidCells-human-pancreas-SS2.loom
# 10  InfiltratingNeoplasticCellsHumanGlioblastoma-human-brain-SS2.loom
# 11                                 Lupus-Dutetre-human-blood-SS2.loom
# 12                             Lymphomyeloid-human-umbilical-SS2.loom
# 13                         THP1StimulationCells-human-breast-SS2.loom
# 14                           dermal-fibroblast-human-abdomen-SS2.loom
# 15                                fetal-maternal-human-blood-SS2.loom
# 16                              fetal-maternal-human-decidua-SS2.loom
# 17                           healthy-diabetes-human-pancreas-SS2.loom
# 18                  interneuron-differentiation-human-embryo-SS2.loom
# 19                                       niches-human-immune-SS2.loom
# 20                                    niches-human-intestine-SS2.loom
# 21                     preimplantation-ESCs-human-blastocyst-SS2.loom
#df[df["Organ"] == "liver"].head()
## todo- create col. for project page.html
pd.set_option("display.max_colwidth", None)
df[df["Organ"] == "blood"]["Url"]
# Out:
# 0     https://service.azul.data.humancellatlas.org/repository/files/feb5f419-da5c-58ac-b866-d5f1fa9e0548?catalog=dcp54&version=2022-01-20T20%3A13%3A43.000000Z
# 4     https://service.azul.data.humancellatlas.org/repository/files/ec0ad12e-9828-54a5-86bf-58a9dbb1e679?catalog=dcp54&version=2021-10-13T03%3A43%3A25.000000Z
# 6     https://service.azul.data.humancellatlas.org/repository/files/43104b26-6f1f-5b14-8f6e-458d5ab05ea4?catalog=dcp54&version=2022-01-19T06%3A05%3A54.000000Z
# 11    https://service.azul.data.humancellatlas.org/repository/files/f02fb30a-1f32-50d0-a3d5-95051ffa5899?catalog=dcp54&version=2022-01-19T14%3A15%3A32.000000Z
# 15    https://service.azul.data.humancellatlas.org/repository/files/95f5f493-304f-5cec-a776-b9e72b97d6c2?catalog=dcp54&version=2021-10-14T16%3A54%3A34.000000Z
# 26    https://service.azul.data.humancellatlas.org/repository/files/8464fdc4-9927-56d7-a244-08a4a0de16c9?catalog=dcp54&version=2021-11-09T21%3A28%3A56.000000Z
# Name: Url, dtype: object

# %%
## Extract Url
urls = df["Url"].tolist()

# %%
## Parallel download
### Use pooch
### async+aiohttp

# %%
import aiohttp
import asyncio

# asynchronous func.
async def fetch(session, url):
    async with session.get(url) as response:
        return await response.text()

connector = aiohttp.TCPConnector(limit=10) # no overloading req.

# Here plug the urls from above
async def main():

    # instantiating a shared session
    async with aiohttp.ClientSession(connector=connector) as session:
        tasks = [fetch(session, url) for url in urls]
        responses = await asyncio.gather(*tasks)
        
        # validate or do smtg else
        for url, response in zip(urls, responses):
            print(f"URL: {url}\nResponse length: {len(response)}\n")

#asyncio.run(main()) ## commented due to weird jupyter behaviour
await main()
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[38], line 24
#      21             print(f"URL: {url}\nResponse length: {len(response)}\n")
#      23 #asyncio.run(main()) ## commented due to weird jupyter behaviour
# ---> 24 await main()
#
# Cell In[38], line 17, in main()
#      15 async with aiohttp.ClientSession(connector=connector) as session:
#      16     tasks = [fetch(session, url) for url in urls]
# ---> 17     responses = await asyncio.gather(*tasks)
#      19     # validate or do smtg else
#      20     for url, response in zip(urls, responses):
#
# Cell In[38], line 7, in fetch(session, url)
#       5 async def fetch(session, url):
#       6     async with session.get(url) as response:
# ----> 7         return await response.text()
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/aiohttp/client_reqrep.py:735, in ClientResponse.text(self, encoding, errors)
#     733 """Read response payload and decode."""
#     734 if self._body is None:
# --> 735     await self.read()
#     737 if encoding is None:
#     738     encoding = self.get_encoding()
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/aiohttp/client_reqrep.py:693, in ClientResponse.read(self)
#     691 if self._body is None:
#     692     try:
# --> 693         self._body = await self.content.read()
#     694         for trace in self._traces:
#     695             await trace.send_response_chunk_received(
#     696                 self.method, self.url, self._body
#     697             )
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/aiohttp/streams.py:426, in StreamReader.read(self, n)
#     424 blocks = []
#     425 while True:
# --> 426     block = await self.readany()
#     427     if not block:
#     428         break
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/aiohttp/streams.py:448, in StreamReader.readany(self)
#     444 # TODO: should be `if` instead of `while`
#     445 # because waiter maybe triggered on chunk end,
#     446 # without feeding any data
#     447 while not self._buffer and not self._eof:
# --> 448     await self._wait("readany")
#     450 return self._read_nowait(-1)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/aiohttp/streams.py:355, in StreamReader._wait(self, func_name)
#     353 try:
#     354     with self._timer:
# --> 355         await waiter
#     356 finally:
#     357     self._waiter = None
#
# CancelledError:

# %%
async def fetch(session, url):
    async with session.head(url) as response:
        return url, response.status

connector = aiohttp.TCPConnector(limit=10) # no overloading req.

async def main():

    async with aiohttp.ClientSession(connector=connector) as session:
        tasks = [fetch(session, url) for url in urls]
        responses = await asyncio.gather(*tasks)

        for url, status in responses:
            print(f"{url} = {status}")

    
await main()
# Out:
# https://service.azul.data.humancellatlas.org/repository/files/feb5f419-da5c-58ac-b866-d5f1fa9e0548?catalog=dcp54&version=2022-01-20T20%3A13%3A43.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/e17ad464-787e-5526-8b5d-f2fcea28cb06?catalog=dcp54&version=2022-01-19T14%3A08%3A08.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/d0e303fb-b679-5968-b814-1ad6c1e6db28?catalog=dcp54&version=2022-01-08T18%3A21%3A57.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/3014ec47-1399-57ca-ab74-c8c296232b9e?catalog=dcp54&version=2021-10-14T20%3A19%3A06.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/ec0ad12e-9828-54a5-86bf-58a9dbb1e679?catalog=dcp54&version=2021-10-13T03%3A43%3A25.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/2dc04008-2d62-5c3f-a6f1-c7cae7ac1009?catalog=dcp54&version=2022-01-08T16%3A18%3A42.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/43104b26-6f1f-5b14-8f6e-458d5ab05ea4?catalog=dcp54&version=2022-01-19T06%3A05%3A54.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/52608937-5b23-5037-8d0e-8f00696e8bcb?catalog=dcp54&version=2022-01-11T18%3A39%3A29.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/f50fbeda-ebb1-59db-ab01-5009313bd1cc?catalog=dcp54&version=2022-01-10T15%3A54%3A23.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/6dcc3ab8-784e-5650-b500-16cc12fed239?catalog=dcp54&version=2022-01-11T14%3A45%3A26.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/127c2bb5-2e16-54a9-abb6-503f1afc41c4?catalog=dcp54&version=2022-01-19T23%3A44%3A07.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/f02fb30a-1f32-50d0-a3d5-95051ffa5899?catalog=dcp54&version=2022-01-19T14%3A15%3A32.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/0ae41a0f-fad2-56c5-b843-fa0fc4f5badb?catalog=dcp54&version=2022-01-19T04%3A13%3A17.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/8b771e65-9a72-5e8c-ad42-3c52831c503e?catalog=dcp54&version=2022-01-11T15%3A33%3A34.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/8f02cde0-e572-5cad-9ec6-bb1278e84283?catalog=dcp54&version=2022-01-19T15%3A22%3A33.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/95f5f493-304f-5cec-a776-b9e72b97d6c2?catalog=dcp54&version=2021-10-14T16%3A54%3A34.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/e6463aeb-bc5a-5ae0-bacc-f6ab621cf3b8?catalog=dcp54&version=2021-10-16T23%3A13%3A04.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/65741d9d-63f9-56c0-994c-b3c202d0b820?catalog=dcp54&version=2021-10-13T09%3A01%3A53.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/29e52cc2-14b8-5eb0-b94b-f115327af47e?catalog=dcp54&version=2021-10-13T17%3A42%3A14.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/57d5bbbf-5c27-5c0c-a32f-46ca08a58650?catalog=dcp54&version=2021-11-18T19%3A15%3A10.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/d8456002-1c4e-5702-9555-6f836f361cb6?catalog=dcp54&version=2021-11-20T07%3A03%3A26.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/f0c778be-3bc2-5e56-b048-9b1acd19860f?catalog=dcp54&version=2022-01-19T17%3A43%3A27.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/a310a2db-5486-5b3c-808a-4e44002c89b9?catalog=dcp54&version=2022-01-19T20%3A45%3A30.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/333119c8-fe4c-5bc1-b879-a9494e3a655d?catalog=dcp54&version=2022-01-19T23%3A34%3A45.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/e1ee2b55-7bce-53a0-b0b4-77f1c98f5a1d?catalog=dcp54&version=2021-10-13T07%3A30%3A43.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/0ea3213c-c896-5d41-b44a-d546f12f925d?catalog=dcp54&version=2022-01-20T15%3A33%3A49.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/8464fdc4-9927-56d7-a244-08a4a0de16c9?catalog=dcp54&version=2021-11-09T21%3A28%3A56.000000Z = 403
# https://service.azul.data.humancellatlas.org/repository/files/733c22aa-6f5a-5055-a147-000e4474b5ab?catalog=dcp54&version=2022-01-19T16%3A16%3A27.000000Z = 403

# %%
# authentication needed # dwld later

# %%
import aiohttp
import asyncio

async def download_file(url, filename):
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            data = await response.read()
            with open(filename, "wb") as f:
                chunk_size = 4096 #adjust?
                async for data in response.content.iter_chunked(chunk_size):
                    f.write(data)

await(download_file("https://unsplash.com/photos/SLgCDEqHav4/download?ixid=M3wxMjA3fDF8MXxhbGx8MXx8fHx8fHx8MTc2MjMzODcwOXw&force=true", "/Users/aman/Desktop/unsplash_image.jpg"))

# %%
import aiohttp
import asyncio
from aiohttp import ClientTimeout

timeout = ClientTimeout(total=None)
headers = {"User-Agent": "Mozilla/5.0"}
connector = aiohttp.TCPConnector(limit=10)

#1 mb chunks
async def download_file(url, filename, chunk_size=1024*1024):
    async with aiohttp.ClientSession(timeout=timeout, headers=headers, connector=connector) as session:
        async with session.get(url) as response:
            if response.status != 200:
                raise Exception(f"Failed: {response.status}")
            
            with open(filename, "wb") as f:
                async for chunk in response.content.iter_chunked(chunk_size):
                    f.write(chunk)

await(download_file("https://unsplash.com/photos/zJD6UVVW_Ck/download?ixid=M3wxMjA3fDB8MXxhbGx8fHx8fHx8fHwxNzYyMzQxODUxfA&force=true", "/Users/aman/Desktop/unsplash_image.jpg"))

# %%
# test with metadata loom file
from aiohttp import ClientTimeout
timeout = ClientTimeout(total=None)
headers = {"User-Agent": "Mozilla/5.0"}

#1 mb chunks
async def download_file(url, filename, chunk_size=1024*1024, retries=3):
    for i in range(retries):
        try:
            connector = aiohttp.TCPConnector(limit=10)
            async with aiohttp.ClientSession(timeout=timeout, headers=headers, connector=connector) as session:
                async with session.get(url) as response:
                    if response.status != 200:
                        raise Exception(f"Failed: {response.status}")
                    
                    with open(filename, "wb") as f:
                        async for chunk in response.content.iter_chunked(chunk_size):
                            f.write(chunk)
            print("Download complete:", filename)
            return
        except Exception as e:
            print(f"Retry {i+1} failed:", e)
            time.sleep(2 ** i) # adjust

await(download_file("https://unsplash.com/photos/I33IeaCFPRY/download?ixid=M3wxMjA3fDB8MXxhbGx8fHx8fHx8fHwxNzYyMzUyNDMyfA&force=true", "/Users/aman/Desktop/unsplash2.jpg"))
# Out:
# Download complete: /Users/aman/Desktop/unsplash2.jpg
