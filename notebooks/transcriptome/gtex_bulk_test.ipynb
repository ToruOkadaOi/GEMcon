# %% [markdown]
# #### GTex

# %%
import pandas as pd
gct_path = "/home/biodata/aman/data_raw/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_tpm.gct"

# show first few lines
with open(gct_path) as fh:
    for _ in range(8):
        print(fh.readline())

## genes = rows and samples/studies as columns
# Out:
# #1.2
#
# 59033	19616
#
# ...

# %%
import pandas as pd

# to get the info about the colums/samples, loading here the attribute table
meta_path = "/home/biodata/aman/data_raw/GTEx_Analysis_v10_Annotations_SampleAttributesDD.xlsx"

meta = pd.read_excel(meta_path)

#print(meta.shape)
print(meta.head())
# Out:
# (128, 58)
#      VARNAME                               VARDESC ACCESS  \
# 0     SAMPID      Sample ID, GTEx Public Sample ID   Open
# 1   SMATSSCR                       Autolysis Score   Open
# 2   SMNABTCH       Nucleic Acid Isolation Batch ID   Open
# 3  SMNABTCHT  Type of nucleic acid isolation batch   Open
# 4  SMNABTCHD  Date of nucleic acid isolation batch   Open
#
#                    DOCFILE                    TYPE UNITS            COMMENT1  \
# 0                      NaN                  string   NaN                 NaN
# 1  PRC Case Summary Report  integer, encoded value   NaN           Autolysis
# 2                    LDACC                  string   NaN  Generated at LDACC
# 3                    LDACC                  string   NaN  Generated at LDACC
# 4                    LDACC                  string   NaN  Generated at LDACC
#
#                                             COMMENT2  VALUES Unnamed: 9  ...  \
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Now to get the sample 

meta = pd.read_csv("/home/biodata/aman/data_raw/GTEx_Analysis_v10_Annotations_SampleAttributesDS.txt", sep="\t")  # this file lists the entirity of samples
# From the GTEx_Analysis_v10_Annotations_SampleAttributesDD.txt file it can be understood that Tissue type is stored as variable SMTSD
brain_ids = meta.loc[meta["SMTSD"] == "Brain - Frontal Cortex (BA9)","SAMPID"].tolist()
brain_ids
# Out:
# /tmp/ipykernel_1459279/1799475374.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv("/home/biodata/aman/data_raw/GTEx_Analysis_v10_Annotations_SampleAttributesDS.txt", sep="\t")
# ['GTEX-1117F-0011-R10a-SM-AHZ7F',
#  'GTEX-1117F-0011-R10b-SM-CYKQ8',
#  'GTEX-1117F-0011-R10b-SM-GI4VE',
#  'GTEX-1117F-0011-R10b-SM-LLLJO',
#  'GTEX-111FC-0011-R10a-SM-AHZ7K',
#  'GTEX-111FC-0011-R10a-SM-CYKQ9',
#  'GTEX-111FC-0011-R10a-SM-GIN8G',
#  'GTEX-111FC-0011-R10a-SM-LUBBG',
#  'GTEX-113JC-0011-R10a-SM-LUBBS',
#  'GTEX-117XS-0011-R10a-SM-AHZ7G',
#  'GTEX-117XS-0011-R10b-SM-GIN8Z',
#  'GTEX-1192W-0011-R10b-SM-GHWOF',
#  'GTEX-1192W-0011-R10b-SM-LVTB2',
#  'GTEX-1192X-0011-R10a-SM-4RXXZ',
#  'GTEX-1192X-0011-R10a-SM-CYKSL',
#  'GTEX-1192X-0011-R10a-SM-DO941',
#  'GTEX-1192X-0011-R10a-SM-GKGNL',
#  'GTEX-11DXW-0011-R10a-SM-AHZNX',
#  'GTEX-11DXW-0011-R10b-SM-GI4VP',
#  'GTEX-11DXY-0011-R10b-SM-AHB9X',
# ...

# %%
import pandas as pd

# main file
gct_path = "/home/biodata/aman/data_raw/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_tpm.gct"

# read only header
header = pd.read_csv(gct_path, sep="\t", skiprows=2, nrows=0).columns.tolist()

# metadata
meta = pd.read_csv(
    "/home/biodata/aman/data_raw/GTEx_Analysis_v10_Annotations_SampleAttributesDS.txt",
    sep="\t"
)

# pick tissue
brain_ids = meta.loc[meta["SMTS"] == "Brain", "SAMPID"].tolist()

# match ids
valid_ids = ["Name"] + list(set(brain_ids).intersection(header))

# read only required columns
tpm = pd.read_csv(gct_path, sep="\t", skiprows=2, usecols=valid_ids)
# Out:
# /tmp/ipykernel_1459279/1378610575.py:9: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv(

# %%
tpm.head()
# Out:
#                 Name  GTEX-1117F-0011-R10b-SM-GI4VE  \
# 0  ENSG00000223972.5                       0.000000
# 1  ENSG00000227232.5                       3.579280
# 2  ENSG00000278267.1                       0.000000
# 3  ENSG00000243485.5                       0.093825
# 4  ENSG00000237613.2                       0.000000
#
#    GTEX-1117F-0011-R11b-SM-GIN8R  GTEX-1117F-0011-R2b-SM-GI4VL  \
# 0                       0.000000                       0.00000
# 1                      10.189300                       2.96650
# 2                       0.000000                       0.00000
# 3                       0.034191                       0.00000
# 4                       0.000000                       0.01766
#
#    GTEX-1117F-0011-R3a-SM-GJ3PJ  GTEX-1117F-0011-R4b-SM-GI4VM  \
# 0                        0.0000                      0.012397
# 1                        3.6828                      3.599210
# 2                        0.0000                      0.000000
# ...

# %%
tpm.describe()
# Out:
#        GTEX-1117F-0011-R10b-SM-GI4VE  GTEX-1117F-0011-R11b-SM-GIN8R  \
# count                   59033.000000                   59033.000000
# mean                       16.939677                      16.939675
# std                       762.650527                     811.317659
# min                         0.000000                       0.000000
# 25%                         0.000000                       0.000000
# 50%                         0.025976                       0.029014
# 75%                         1.573410                       1.613420
# max                     82528.100000                   88556.500000
#
#        GTEX-1117F-0011-R2b-SM-GI4VL  GTEX-1117F-0011-R3a-SM-GJ3PJ  \
# count                  59033.000000                  59033.000000
# mean                      16.939685                     16.939677
# std                      963.340736                    794.219387
# min                        0.000000                      0.000000
# ...

# %%
import pandas as pd

gct_path = "/home/biodata/aman/data_raw/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_median_tpm.gct.gz"

# read only header
header = pd.read_csv(gct_path, sep="\t", skiprows=2, nrows=0).columns.tolist()

# metadata
meta = pd.read_csv(
    "/home/biodata/aman/data_raw/GTEx_Analysis_v10_Annotations_SampleAttributesDS.txt",
    sep="\t"
)

# pick tissue
brain_ids = meta.loc[meta["SMTS"] == "Brain", "SAMPID"].tolist()

# match ids
valid_ids = ["Name"] + list(set(brain_ids).intersection(header))

# read only required columns
tpm_median = pd.read_csv(gct_path, sep="\t", skiprows=2, usecols=valid_ids)
# Out:
# /tmp/ipykernel_1459279/478133302.py:9: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv(

# %%
tpm_median
# Out:
#                     Name
# 0      ENSG00000223972.5
# 1      ENSG00000227232.5
# 2      ENSG00000278267.1
# 3      ENSG00000243485.5
# 4      ENSG00000237613.2
# ...                  ...
# 59028  ENSG00000198695.2
# 59029  ENSG00000210194.1
# 59030  ENSG00000198727.2
# 59031  ENSG00000210195.2
# 59032  ENSG00000210196.2
#
# [59033 rows x 1 columns]

# %%
tpm_median = pd.read_csv(
    "/home/biodata/aman/data_raw/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_median_tpm.gct.gz",
    sep="\t", skiprows=2
)

tpm_median
# Out:
#                     Name  Description  Adipose_Subcutaneous  \
# 0      ENSG00000223972.5      DDX11L1               0.00000
# 1      ENSG00000227232.5       WASH7P               3.99789
# 2      ENSG00000278267.1    MIR6859-1               0.00000
# 3      ENSG00000243485.5  MIR1302-2HG               0.00000
# 4      ENSG00000237613.2      FAM138A               0.00000
# ...                  ...          ...                   ...
# 59028  ENSG00000198695.2       MT-ND6            3479.95000
# 59029  ENSG00000210194.1        MT-TE               9.66208
# 59030  ENSG00000198727.2       MT-CYB           23813.90000
# 59031  ENSG00000210195.2        MT-TT               0.00000
# 59032  ENSG00000210196.2        MT-TP               1.27003
#
#        Adipose_Visceral_Omentum  Adrenal_Gland  Artery_Aorta  Artery_Coronary  \
# 0                      0.000000       0.000000        0.0000          0.00000
# 1                      3.178150       2.673080        4.0708          3.87547
# ...

# %%
tpm_median.columns
# Out:
# Index(['Name', 'Description', 'Adipose_Subcutaneous',
#        'Adipose_Visceral_Omentum', 'Adrenal_Gland', 'Artery_Aorta',
#        'Artery_Coronary', 'Artery_Tibial', 'Bladder', 'Brain_Amygdala',
#        'Brain_Anterior_cingulate_cortex_BA24', 'Brain_Caudate_basal_ganglia',
#        'Brain_Cerebellar_Hemisphere', 'Brain_Cerebellum', 'Brain_Cortex',
#        'Brain_Frontal_Cortex_BA9', 'Brain_Hippocampus', 'Brain_Hypothalamus',
#        'Brain_Nucleus_accumbens_basal_ganglia', 'Brain_Putamen_basal_ganglia',
#        'Brain_Spinal_cord_cervical_c-1', 'Brain_Substantia_nigra',
#        'Breast_Mammary_Tissue', 'Cells_Cultured_fibroblasts',
#        'Cells_EBV-transformed_lymphocytes', 'Cervix_Ectocervix',
#        'Cervix_Endocervix', 'Colon_Sigmoid', 'Colon_Transverse',
#        'Colon_Transverse_Mixed_Cell', 'Colon_Transverse_Mucosa',
#        'Colon_Transverse_Muscularis', 'Esophagus_Gastroesophageal_Junction',
# ...

# %% [markdown]
# ### TPM files for these can individually be downloaded tho!
#
# ![image.png](attachment:image.png)

# %%
brain = tpm_median[["Name", "Brain_Cortex"]]
brain.columns = ["gene", "expression"]
brain
# Out:
#                     gene    expression
# 0      ENSG00000223972.5      0.000000
# 1      ENSG00000227232.5      2.462830
# 2      ENSG00000278267.1      0.000000
# 3      ENSG00000243485.5      0.026819
# 4      ENSG00000237613.2      0.000000
# ...                  ...           ...
# 59028  ENSG00000198695.2   7227.840000
# 59029  ENSG00000210194.1     17.595800
# 59030  ENSG00000198727.2  30917.800000
# 59031  ENSG00000210195.2      0.999367
# 59032  ENSG00000210196.2      2.191690
#
# [59033 rows x 2 columns]

# %%
meta["SMTS"].value_counts() # SMTSD - tissue type detailed; Check
# Out:
# SMTS
# Brain              8035
# Blood              4717
# Skin               4469
# Esophagus          3394
# Blood Vessel       3286
# Adipose Tissue     2461
# Muscle             2352
# Heart              2138
# Colon              2085
# Thyroid            2033
# Lung               1892
# Nerve              1285
# Breast              992
# Pancreas            961
# Testis              950
# Stomach             950
# Prostate            745
# Adrenal Gland       733
# Pituitary           672
# Liver               598
# Ovary               581
# Spleen              570
# Small Intestine     432
# Salivary Gland      389
# Uterus              352
# Vagina              348
# Kidney              318
# Bone Marrow         217
# Bladder             134
# Cervix Uteri         88
# Fallopian Tube       54
# Name: count, dtype: int64

# %%
# In GTEx_Analysis_v10_Annotations_SampleAttributesDD file; SMSTYP - Indicates whether sample is a tumor or a normal # BBut these are access-protected

# %%
import pandas as pd

# median file
median_path = "/home/biodata/aman/data_raw/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_median_tpm.gct.gz"

# load
tpm_median = pd.read_csv(median_path, sep="\t", skiprows=2)

# choose exactly ONE region (example: Brain - Cortex)
region = "Brain_Cortex"

# extract only that tissue expression
brain_expr = tpm_median[["Name", region]]
brain_expr.columns = ["gene_id", "tpm"]

# save
#brain_expr.to_csv("brain_cortex_GTEx_median_expression.csv", index=False)

brain_expr.head()
# Out:
#              gene_id       tpm
# 0  ENSG00000223972.5  0.000000
# 1  ENSG00000227232.5  2.462830
# 2  ENSG00000278267.1  0.000000
# 3  ENSG00000243485.5  0.026819
# 4  ENSG00000237613.2  0.000000

# %%
# This way all tisuue wise median-TPM norm'd expression data can be taken.

# %% [markdown]
# ##### TEST 2

# %%
import pandas as pd
tpm_median = pd.read_csv("/home/biodata/aman/data/data_raw/gene_tpm_v10_brain_cerebellum.gct.gz", sep="\t", skiprows=2) # tissue = cerebellum only
tpm_median
# Out:
#                     Name  Description  GTEX-111FC-3326-SM-5GZYV  \
# 0      ENSG00000223972.5      DDX11L1                   0.00000
# 1      ENSG00000227232.5       WASH7P                   7.48937
# 2      ENSG00000278267.1    MIR6859-1                   0.78636
# 3      ENSG00000243485.5  MIR1302-2HG                   0.00000
# 4      ENSG00000237613.2      FAM138A                   0.00000
# ...                  ...          ...                       ...
# 59028  ENSG00000198695.2       MT-ND6                6127.33000
# 59029  ENSG00000210194.1        MT-TE                  13.17440
# 59030  ENSG00000198727.2       MT-CYB               31536.30000
# 59031  ENSG00000210195.2        MT-TT                   1.62038
# 59032  ENSG00000210196.2        MT-TP                   1.57272
#
#        GTEX-1128S-2826-SM-5N9DI  GTEX-117XS-3126-SM-5GIDP  \
# 0                       0.00000                  0.037646
# 1                       9.06647                  7.940120
# ...

# %%
tpm_median.columns # multi samples ---> change how troppo reads # TODO
# Out:
# Index(['Name', 'Description', 'GTEX-111FC-3326-SM-5GZYV',
#        'GTEX-1128S-2826-SM-5N9DI', 'GTEX-117XS-3126-SM-5GIDP',
#        'GTEX-1192X-3226-SM-5987D', 'GTEX-11DXW-1026-SM-5H11K',
#        'GTEX-11DXY-3126-SM-5N9BT', 'GTEX-11DYG-2926-SM-5H132',
#        'GTEX-11DZ1-2926-SM-5A5KI',
#        ...
#        'GTEX-ZAJG-3026-SM-5HL92', 'GTEX-ZAK1-2926-SM-5HL9S',
#        'GTEX-ZDXO-2926-SM-4WKFM', 'GTEX-ZF28-2926-SM-4WKG1',
#        'GTEX-ZUA1-2926-SM-59HL3', 'GTEX-ZVT3-2926-SM-5GU6M',
#        'GTEX-ZVZQ-2826-SM-HL9U2', 'GTEX-ZYFD-2926-SM-5GID9',
#        'GTEX-ZYY3-3026-SM-5GIEJ', 'GTEX-ZZPT-2926-SM-5EQ5S'],
#       dtype='object', length=268)

# %%
subset = tpm_median.iloc[:, [0, 2]] # first sampl
subset
# Out:
#                     Name  GTEX-111FC-3326-SM-5GZYV
# 0      ENSG00000223972.5                   0.00000
# 1      ENSG00000227232.5                   7.48937
# 2      ENSG00000278267.1                   0.78636
# 3      ENSG00000243485.5                   0.00000
# 4      ENSG00000237613.2                   0.00000
# ...                  ...                       ...
# 59028  ENSG00000198695.2                6127.33000
# 59029  ENSG00000210194.1                  13.17440
# 59030  ENSG00000198727.2               31536.30000
# 59031  ENSG00000210195.2                   1.62038
# 59032  ENSG00000210196.2                   1.57272
#
# [59033 rows x 2 columns]

# %%
subset.to_csv("bulk_expr_data_cerebellum.csv")

# %%
import pandas as pd

df = pd.read_csv("/home/biodata/aman/data/data_raw/bulk_expr_data_cerebellum.csv")

# Strip version numbers from the ENSEMBL column ("Name")
df["Name"] = df["Name"].astype(str).str.split(".").str[0]

df = df[["Name", "GTEX-111FC-3326-SM-5GZYV"]] 
df.head()
# Out:
#               Name  GTEX-111FC-3326-SM-5GZYV
# 0  ENSG00000223972                   0.00000
# 1  ENSG00000227232                   7.48937
# 2  ENSG00000278267                   0.78636
# 3  ENSG00000243485                   0.00000
# 4  ENSG00000237613                   0.00000

# %%
df.to_csv("/home/biodata/aman/data/data_raw/bulk_expr_data_cerebellum_sanitized.csv", index=False)
