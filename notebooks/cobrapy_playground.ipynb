# %%
import cobra as cp

# %%
options = 'options_MBA'

# %%
options
# Out:
# 'options_MBA'

# %%
cp.createTissueSpecificModel
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cp.createTissueSpecificModel
#
# AttributeError: module 'cobra' has no attribute 'createTissueSpecificModel'
