# %%
import requests

def walk(obj):
    if isinstance(obj, dict):
        for v in obj.values():
            yield from walk(v)
    elif isinstance(obj, list):
        for item in obj:
            yield from walk(item)
    else:
        return
    yield obj

def get_all_urls(project_id: str):
    url = f"https://gtexportal.org/api/v2/dataset/openAccessFilesMetadata?project_id={project_id}"
    data = requests.get(url).json()
    urls = []
    for node in walk(data):
        if isinstance(node, dict) and node.get("url"):
            urls.append(node["url"])
    return urls

urls = get_all_urls("adult-gtex")

for u in urls:
    print(u)
# Out:
# https://storage.googleapis.com/adult-gtex/additional_GTEx_datasets/v6p/coexpression_networks/coexpression_networks_v6p.zip
# https://storage.googleapis.com/adult-gtex/additional_GTEx_datasets/v8/outlier_calls/GTEx_v8_outlier_calls.zip
# https://storage.googleapis.com/adult-gtex/annotations/v10/metadata-files/GTEx_Analysis_v10_Annotations_SampleAttributesDD.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v10/metadata-files/GTEx_Analysis_v10_Annotations_SampleAttributesDS.txt
# https://storage.googleapis.com/adult-gtex/annotations/v10/metadata-files/GTEx_Analysis_v10_Annotations_SubjectPhenotypesDD.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v10/metadata-files/GTEx_Analysis_v10_Annotations_SubjectPhenotypesDS.txt
# https://storage.googleapis.com/adult-gtex/annotations/v10/metadata-files/GTEx_Analysis_v10_Sample_Tissue_Changes_From_v8.txt
# https://storage.googleapis.com/adult-gtex/annotations/v10/small-RNA/smallRNA.filtered_annotated_031725.txt
# https://storage.googleapis.com/adult-gtex/annotations/v3/metadata-files/GTEx_Analysis_Annotations_SampleCounts__Pilot_V3.txt
# https://storage.googleapis.com/adult-gtex/annotations/v3/metadata-files/GTEx_Analysis_Annotations_Sample_DD__Pilot_V3.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v3/metadata-files/GTEx_Analysis_Annotations_Sample_DS__Pilot_V3.txt
# https://storage.googleapis.com/adult-gtex/annotations/v3/metadata-files/GTEx_Analysis_Annotations_Subject_DD__Pilot_V3.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v3/metadata-files/GTEx_Analysis_Annotations_Subject_DS__Pilot_V3.txt
# https://storage.googleapis.com/adult-gtex/annotations/v4/metadata-files/GTEx_Data_V4_Annotations_SampleAttributesDD.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v4/metadata-files/GTEx_Data_V4_Annotations_SampleAttributesDS.txt
# https://storage.googleapis.com/adult-gtex/annotations/v4/metadata-files/GTEx_Data_V4_Annotations_SampleCounts.txt
# https://storage.googleapis.com/adult-gtex/annotations/v4/metadata-files/GTEx_Data_V4_Annotations_SubjectPhenotypes_DD.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v4/metadata-files/GTEx_Data_V4_Annotations_SubjectPhenotypes_DS.txt
# https://storage.googleapis.com/adult-gtex/annotations/v6/metadata-files/GTEx_Data_V6_Annotations_SampleAttributesDD.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v6/metadata-files/GTEx_Data_V6_Annotations_SampleAttributesDS.txt
# https://storage.googleapis.com/adult-gtex/annotations/v6/metadata-files/GTEx_Data_V6_Annotations_SubjectPhenotypesDS.txt
# https://storage.googleapis.com/adult-gtex/annotations/v6/metadata-files/GTEx_Data_V6_Annotations_SubjectPhenotypes_DD.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v6p/metadata-files/GTEx_Data_V6_Annotations_SampleAttributesDD.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v6p/metadata-files/GTEx_Data_V6_Annotations_SampleAttributesDS.txt
# https://storage.googleapis.com/adult-gtex/annotations/v6p/metadata-files/GTEx_Data_V6_Annotations_SubjectPhenotypesDS.txt
# https://storage.googleapis.com/adult-gtex/annotations/v6p/metadata-files/GTEx_Data_V6_Annotations_SubjectPhenotypes_DD.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v7/metadata-files/GTEx_Analysis_v7_Annotations_SampleAttributesDD.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v7/metadata-files/GTEx_Analysis_v7_Annotations_SubjectPhenotypesDD.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v7/metadata-files/GTEx_v7_Annotations_SampleAttributesDS.txt
# https://storage.googleapis.com/adult-gtex/annotations/v7/metadata-files/GTEx_v7_Annotations_SubjectPhenotypesDS.txt
# https://storage.googleapis.com/adult-gtex/annotations/v8/metadata-files/GTEx_Analysis_v8_Annotations_SampleAttributesDD.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v8/metadata-files/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt
# https://storage.googleapis.com/adult-gtex/annotations/v8/metadata-files/GTEx_Analysis_v8_Annotations_SubjectPhenotypesDD.xlsx
# https://storage.googleapis.com/adult-gtex/annotations/v8/metadata-files/GTEx_Analysis_v8_Annotations_SubjectPhenotypesDS.txt
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RNASeQCv2.4.2_exon_reads.parquet
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_median_tpm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_reads.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_tpm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_tpm_lcm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RSEMv1.3.3_transcripts_expected_count.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RSEMv1.3.3_transcripts_tpm.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_STARv2.7.10a_junctions.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_adipose_subcutaneous.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_adipose_visceral_omentum.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_adrenal_gland.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_artery_aorta.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_artery_coronary.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_artery_tibial.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_bladder.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_amygdala.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_anterior_cingulate_cortex_ba24.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_caudate_basal_ganglia.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_cerebellar_hemisphere.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_cerebellum.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_cortex.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_frontal_cortex_ba9.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_hippocampus.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_hypothalamus.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_nucleus_accumbens_basal_ganglia.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_putamen_basal_ganglia.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_spinal_cord_cervical_c-1.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_substantia_nigra.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_breast_mammary_tissue.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_cells_cultured_fibroblasts.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_cells_ebv-transformed_lymphocytes.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_cervix_ectocervix.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_cervix_endocervix.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_colon_sigmoid.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_colon_transverse.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_esophagus_gastroesophageal_junction.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_esophagus_mucosa.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_esophagus_muscularis.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_fallopian_tube.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_heart_atrial_appendage.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_heart_left_ventricle.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_kidney_cortex.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_kidney_medulla.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_liver.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_lung.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_minor_salivary_gland.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_muscle_skeletal.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_nerve_tibial.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_ovary.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_pancreas.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_pituitary.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_prostate.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_skin_not_sun_exposed_suprapubic.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_skin_sun_exposed_lower_leg.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_small_intestine_terminal_ileum.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_spleen.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_stomach.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_testis.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_thyroid.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_uterus.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_vagina.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_whole_blood.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_adipose_subcutaneous.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_adipose_visceral_omentum.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_adrenal_gland.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_artery_aorta.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_artery_coronary.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_artery_tibial.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_bladder.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_amygdala.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_anterior_cingulate_cortex_ba24.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_caudate_basal_ganglia.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_cerebellar_hemisphere.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_cerebellum.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_cortex.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_frontal_cortex_ba9.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_hippocampus.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_hypothalamus.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_nucleus_accumbens_basal_ganglia.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_putamen_basal_ganglia.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_spinal_cord_cervical_c-1.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_substantia_nigra.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_breast_mammary_tissue.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_cells_cultured_fibroblasts.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_cells_ebv-transformed_lymphocytes.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_cervix_ectocervix.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_cervix_endocervix.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_colon_sigmoid.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_colon_transverse.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_esophagus_gastroesophageal_junction.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_esophagus_mucosa.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_esophagus_muscularis.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_fallopian_tube.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_heart_atrial_appendage.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_heart_left_ventricle.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_kidney_cortex.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_kidney_medulla.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_liver.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_lung.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_minor_salivary_gland.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_muscle_skeletal.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_nerve_tibial.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_ovary.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_pancreas.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_pituitary.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_prostate.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_skin_not_sun_exposed_suprapubic.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_skin_sun_exposed_lower_leg.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_small_intestine_terminal_ileum.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_spleen.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_stomach.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_testis.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_thyroid.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_uterus.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_vagina.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_whole_blood.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/small-RNA/GTEx_Analysis_v10_smallRNA_gene_reads_2025_03_17.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/small-RNA/README.pdf
# https://storage.googleapis.com/adult-gtex/bulk-gex/v10/small-RNA/miRNA_TPM_matrix_PORTAL_2025_03_17.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v3/rna-seq/GTEx_Analysis_RNA-seq_Flux1.2.3_intron_fractcovered__Pilot_V3.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v3/rna-seq/GTEx_Analysis_RNA-seq_Flux1.2.3_intron_readcount__Pilot_V3.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v3/rna-seq/GTEx_Analysis_RNA-seq_Flux1.2.3_junction_readcount__Pilot_V3.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v3/rna-seq/GTEx_Analysis_RNA-seq_Flux1.2.3_transcript_readcount__Pilot_V3.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v3/rna-seq/GTEx_Analysis_RNA-seq_Flux1.2.3_transcript_rpkm__Pilot_V3.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v3/rna-seq/GTEx_Analysis_RNA-seq_RNA-SeQCv1.1.8_exon_reads__Pilot_V3.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v3/rna-seq/GTEx_Analysis_RNA-seq_RNA-SeQCv1.1.8_gene_reads__Pilot_V3_patch1.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v3/rna-seq/GTEx_Analysis_RNA-seq_RNA-SeQCv1.1.8_gene_rpkm__Pilot_V3_patch1.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v4/rna-seq/GTEx_Analysis_V4_RNA-seq_Flux1.6_intron_fraccov.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v4/rna-seq/GTEx_Analysis_V4_RNA-seq_Flux1.6_intron_reads.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v4/rna-seq/GTEx_Analysis_V4_RNA-seq_Flux1.6_junction_reads.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v4/rna-seq/GTEx_Analysis_V4_RNA-seq_Flux1.6_transcript_reads.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v4/rna-seq/GTEx_Analysis_V4_RNA-seq_Flux1.6_transcript_rpkm.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v4/rna-seq/GTEx_Analysis_V4_RNA-seq_RNA-SeQCv1.1.8_exon_reads.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v4/rna-seq/GTEx_Analysis_V4_RNA-seq_RNA-SeQCv1.1.8_gene_reads.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v4/rna-seq/GTEx_Analysis_V4_RNA-seq_RNA-SeQCv1.1.8_gene_rpkm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v6/rna-seq/GTEx_Analysis_v6_RNA-seq_Flux1.6_intron_fraccov.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v6/rna-seq/GTEx_Analysis_v6_RNA-seq_Flux1.6_intron_reads.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v6/rna-seq/GTEx_Analysis_v6_RNA-seq_Flux1.6_junction_reads.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v6/rna-seq/GTEx_Analysis_v6_RNA-seq_Flux1.6_transcript_reads.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v6/rna-seq/GTEx_Analysis_v6_RNA-seq_Flux1.6_transcript_rpkm.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v6/rna-seq/GTEx_Analysis_v6_RNA-seq_RNA-SeQCv1.1.8_exon_reads.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v6/rna-seq/GTEx_Analysis_v6_RNA-seq_RNA-SeQCv1.1.8_gene_median_rpkm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v6/rna-seq/GTEx_Analysis_v6_RNA-seq_RNA-SeQCv1.1.8_gene_reads.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v6/rna-seq/GTEx_Analysis_v6_RNA-seq_RNA-SeQCv1.1.8_gene_rpkm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v6p/rna-seq/GTEx_Analysis_v6p_RNA-seq_RNA-SeQCv1.1.8_gene_median_rpkm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v6p/rna-seq/GTEx_Analysis_v6p_RNA-seq_RNA-SeQCv1.1.8_gene_reads.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v6p/rna-seq/GTEx_Analysis_v6p_RNA-seq_RNA-SeQCv1.1.8_gene_rpkm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v7/rna-seq/GTEx_Analysis_2016-01-15_v7_RNASeQCv1.1.8_exon_reads.parquet
# https://storage.googleapis.com/adult-gtex/bulk-gex/v7/rna-seq/GTEx_Analysis_2016-01-15_v7_RNASeQCv1.1.8_gene_median_tpm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v7/rna-seq/GTEx_Analysis_2016-01-15_v7_RNASeQCv1.1.8_gene_reads.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v7/rna-seq/GTEx_Analysis_2016-01-15_v7_RNASeQCv1.1.8_gene_tpm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v7/rna-seq/GTEx_Analysis_2016-01-15_v7_RSEMv1.2.22_transcript_expected_count.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v7/rna-seq/GTEx_Analysis_2016-01-15_v7_RSEMv1.2.22_transcript_tpm.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v7/rna-seq/GTEx_Analysis_2016-01-15_v7_STARv2.4.2a_junctions.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_exon_reads.parquet
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_median_tpm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_reads.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RSEMv1.3.0_transcript_expected_count.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RSEMv1.3.0_transcript_tpm.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_STARv2.5.3a_junctions.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_adipose_subcutaneous.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_adipose_visceral_omentum.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_adrenal_gland.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_artery_aorta.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_artery_coronary.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_artery_tibial.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_bladder.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_amygdala.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_anterior_cingulate_cortex_ba24.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_caudate_basal_ganglia.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_cerebellar_hemisphere.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_cerebellum.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_cortex.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_frontal_cortex_ba9.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_hippocampus.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_hypothalamus.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_nucleus_accumbens_basal_ganglia.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_putamen_basal_ganglia.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_spinal_cord_cervical_c-1.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_brain_substantia_nigra.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_breast_mammary_tissue.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_cells_cultured_fibroblasts.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_cells_ebv-transformed_lymphocytes.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_cervix_ectocervix.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_cervix_endocervix.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_colon_sigmoid.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_colon_transverse.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_esophagus_gastroesophageal_junction.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_esophagus_mucosa.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_esophagus_muscularis.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_fallopian_tube.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_heart_atrial_appendage.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_heart_left_ventricle.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_kidney_cortex.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_kidney_medulla.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_liver.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_lung.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_minor_salivary_gland.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_muscle_skeletal.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_nerve_tibial.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_ovary.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_pancreas.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_pituitary.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_prostate.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_skin_not_sun_exposed_suprapubic.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_skin_sun_exposed_lower_leg.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_small_intestine_terminal_ileum.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_spleen.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_stomach.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_testis.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_thyroid.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_uterus.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_vagina.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/counts-by-tissue/gene_reads_2017-06-05_v8_whole_blood.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_adipose_subcutaneous.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_adipose_visceral_omentum.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_adrenal_gland.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_artery_aorta.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_artery_coronary.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_artery_tibial.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_bladder.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_amygdala.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_anterior_cingulate_cortex_ba24.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_caudate_basal_ganglia.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_cerebellar_hemisphere.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_cerebellum.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_cortex.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_frontal_cortex_ba9.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_hippocampus.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_hypothalamus.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_nucleus_accumbens_basal_ganglia.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_putamen_basal_ganglia.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_spinal_cord_cervical_c-1.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_brain_substantia_nigra.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_breast_mammary_tissue.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_cells_cultured_fibroblasts.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_cells_ebv-transformed_lymphocytes.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_cervix_ectocervix.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_cervix_endocervix.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_colon_sigmoid.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_colon_transverse.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_esophagus_gastroesophageal_junction.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_esophagus_mucosa.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_esophagus_muscularis.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_fallopian_tube.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_heart_atrial_appendage.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_heart_left_ventricle.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_kidney_cortex.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_kidney_medulla.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_liver.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_lung.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_minor_salivary_gland.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_muscle_skeletal.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_nerve_tibial.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_ovary.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_pancreas.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_pituitary.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_prostate.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_skin_not_sun_exposed_suprapubic.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_skin_sun_exposed_lower_leg.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_small_intestine_terminal_ileum.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_spleen.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_stomach.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_testis.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_thyroid.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_uterus.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_vagina.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/tpms-by-tissue/gene_tpm_2017-06-05_v8_whole_blood.gct.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/single-tissue-cis-qtl/GTEx_Analysis_v10_apaQTL.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/single-tissue-cis-qtl/GTEx_Analysis_v10_eQTL.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/single-tissue-cis-qtl/GTEx_Analysis_v10_eQTL_covariates.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/single-tissue-cis-qtl/GTEx_Analysis_v10_eQTL_expression_matrices.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/single-tissue-cis-qtl/GTEx_Analysis_v10_sQTL.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/single-tissue-cis-qtl/GTEx_Analysis_v10_sQTL_covariates.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/single-tissue-cis-qtl/GTEx_Analysis_v10_sQTL_groups.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/single-tissue-cis-qtl/GTEx_Analysis_v10_sQTL_phenotype_matrices.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/single-tissue-cis-qtl/README_eQTL_v10.txt
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/small-RNA/GTEx_Analysis_v10_smallRNA_eQTL.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/small-RNA/GTEx_Analysis_v10_smallRNA_eQTL_covariates.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/small-RNA/GTEx_Analysis_v10_smallRNA_eQTL_expression_matrices.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/small-RNA/README_eQTL_v10.txt
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/susie-qtl/GTEx_v10_SuSiE_apaQTL.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/susie-qtl/GTEx_v10_SuSiE_eQTL.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v10/susie-qtl/GTEx_v10_SuSiE_sQTL.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/multi-tissue-qtl/Multi_tissue_eQTL_GTEx_Pilot_Phase_datasets.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/multi-tissue-qtl/README
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/single-tissue-cis-qtl/All-snp-gene-pair-results-sQTLseeker-merged.tgz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/single-tissue-cis-qtl/Altrans_All_sQTLs_bestPerLink.tgz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/single-tissue-cis-qtl/Altrans_FDR05_bestPerLink.tgz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/single-tissue-cis-qtl/GTEx_Analysis_Pilot_V3_all-snp-gene-associations.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/single-tissue-cis-qtl/GTEx_Analysis_Pilot_V3_eQTLs.tgz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/single-tissue-cis-qtl/GTEx_Analysis_V3_eQTLInputFiles_covariates.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/single-tissue-cis-qtl/GTEx_Analysis_V3_eQTLInputFiles_geneLevelNormalizedExpression.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/single-tissue-cis-qtl/README.altrans
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/single-tissue-cis-qtl/README.eqtls
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/single-tissue-cis-qtl/README.sqtlseeker
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v3/single-tissue-cis-qtl/sQTLs-sQTLseeker-merged.tgz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v4/single-tissue-cis-qtl/GTEx_Analysis_V4_all-snp-gene-associations.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v4/single-tissue-cis-qtl/GTEx_Analysis_V4_eQTLInputFiles_covariates.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v4/single-tissue-cis-qtl/GTEx_Analysis_V4_eQTLInputFiles_geneLevelNormalizedExpression.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v4/single-tissue-cis-qtl/GTEx_Analysis_V4_eQTLs.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v4/single-tissue-cis-qtl/README.eqtls
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/GTEx_Analysis_V6_all-snp-gene-associations.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/GTEx_Analysis_V6_eQTLInputFiles_covariates.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/GTEx_Analysis_V6_eQTLInputFiles_geneLevelNormalizedExpressionMatrices.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/GTEx_Analysis_V6_eQTLs.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/README.eqtls
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Adipose_Subcutaneous_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Adipose_Visceral_Omentum_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Adrenal_Gland_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Artery_Aorta_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Artery_Coronary_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Artery_Tibial_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Brain_Anterior_cingulate_cortex_BA24_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Brain_Caudate_basal_ganglia_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Brain_Cerebellar_Hemisphere_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Brain_Cerebellum_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Brain_Cortex_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Brain_Frontal_Cortex_BA9_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Brain_Hippocampus_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Brain_Hypothalamus_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Brain_Nucleus_accumbens_basal_ganglia_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Brain_Putamen_basal_ganglia_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Breast_Mammary_Tissue_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Cells_EBV-transformed_lymphocytes_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Cells_Transformed_fibroblasts_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Colon_Sigmoid_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Colon_Transverse_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Esophagus_Gastroesophageal_Junction_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Esophagus_Mucosa_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Esophagus_Muscularis_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Heart_Atrial_Appendage_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Heart_Left_Ventricle_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Liver_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Lung_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Muscle_Skeletal_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Nerve_Tibial_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Ovary_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Pancreas_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Pituitary_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Prostate_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Skin_Not_Sun_Exposed_Suprapubic_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Skin_Sun_Exposed_Lower_leg_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Small_Intestine_Terminal_Ileum_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Spleen_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Stomach_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Testis_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Thyroid_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Uterus_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Vagina_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6/single-tissue-cis-qtl/all_snp_gene_associations/Whole_Blood_Analysis_cis-eQTLs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v6p/single-tissue-cis-qtl/GTEx_Analysis_v6p_all-associations.tar
# ...
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v7/single-tissue-cis-qtl/all_snp_gene_associations/Testis.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v7/single-tissue-cis-qtl/all_snp_gene_associations/Thyroid.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v7/single-tissue-cis-qtl/all_snp_gene_associations/Uterus.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v7/single-tissue-cis-qtl/all_snp_gene_associations/Vagina.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v7/single-tissue-cis-qtl/all_snp_gene_associations/Whole_Blood.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/cell-type-iqtl/GTEx_Analysis_v8_ieQTL.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/cell-type-iqtl/GTEx_Analysis_v8_isQTL.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/cell-type-iqtl/GTEx_Analysis_v8_xCell_scores_7_celltypes.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/GTEx_Analysis_v8_edQTL.README.txt
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/GTEx_Analysis_v8_edQTL.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/GTEx_Analysis_v8_edQTL_covariates.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/GTEx_Analysis_v8_edQTL_phenotype_matrices.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Adipose-Subcutaneous.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Adipose-Visceral-Omentum.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Adrenal-Gland.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Artery-Aorta.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Artery-Coronary.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Artery-Tibial.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Amygdala.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Anterior-cingulate-cortex-BA24.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Caudate-basal-ganglia.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Cerebellar-Hemisphere.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Cerebellum.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Cortex.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Frontal-Cortex-BA9.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Hippocampus.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Hypothalamus.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Nucleus-accumbens-basal-ganglia.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Putamen-basal-ganglia.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Spinal-cord-cervical-c-1.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Brain-Substantia-nigra.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Breast-Mammary-Tissue.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Cells-Cultured-fibroblasts.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Cells-EBV-transformed-lymphocytes.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Colon-Sigmoid.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Colon-Transverse.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Esophagus-Gastroesophageal-Junction.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Esophagus-Mucosa.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Esophagus-Muscularis.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Heart-Atrial-Appendage.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Heart-Left-Ventricle.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Kidney-Cortex.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Liver.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Lung.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Minor-Salivary-Gland.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Muscle-Skeletal.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Nerve-Tibial.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Ovary.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Pancreas.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Pituitary.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Prostate.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Skin-Not-Sun-Exposed-Suprapubic.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Skin-Sun-Exposed-Lower-leg.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Small-Intestine-Terminal-Ileum.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Spleen.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Stomach.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Testis.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Thyroid.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Uterus.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Vagina.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/editing-qtl/all_associations/Whole-Blood.nominal.allpairs.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/fine-mapping-cis-eqtl/GTEx_v8_finemapping_CAVIAR.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/fine-mapping-cis-eqtl/GTEx_v8_finemapping_CaVEMaN.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/fine-mapping-cis-eqtl/GTEx_v8_finemapping_DAPG.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/multi-tissue-qtl/GTEx_Analysis_v8.metasoft.txt.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/multi-tissue-qtl/gtex_v8_cis_qtls_mashr.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/sb-eqtl/GTEx_Analysis_v8_sbeQTLs.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/sb-eqtl/GTEx_Analysis_v8_sbgenes.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/GTEx_Analysis_v8_eQTL.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/GTEx_Analysis_v8_eQTL_EUR.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/GTEx_Analysis_v8_eQTL_covariates.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/GTEx_Analysis_v8_eQTL_expression_matrices.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/GTEx_Analysis_v8_eQTL_independent.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/GTEx_Analysis_v8_sQTL.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/GTEx_Analysis_v8_sQTL_EUR.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/GTEx_Analysis_v8_sQTL_covariates.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/GTEx_Analysis_v8_sQTL_groups.tar.gz
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/GTEx_Analysis_v8_sQTL_independent.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/GTEx_Analysis_v8_sQTL_phenotype_matrices.tar
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/GTEx_v8_pb_eQTLs.fdr_0.25.high_confidence_set.xlsx
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-cis-qtl/README_eQTL_v8.txt
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-trans-qtl/GTEx_Analysis_v8_trans_eGenes_fdr05.txt
# https://storage.googleapis.com/adult-gtex/bulk-qtl/v8/single-tissue-trans-qtl/GTEx_Analysis_v8_trans_sGenes_fdr05.txt
# https://storage.googleapis.com/adult-gtex/haplotype-expression/v8/haplotype-expression-matrices/phASER.README.txt
# https://storage.googleapis.com/adult-gtex/haplotype-expression/v8/haplotype-expression-matrices/phASER_GTEx_v8_matrix.gw_phased.txt.gz
# https://storage.googleapis.com/adult-gtex/haplotype-expression/v8/haplotype-expression-matrices/phASER_GTEx_v8_matrix.txt.gz
# https://storage.googleapis.com/adult-gtex/haplotype-expression/v8/haplotype-expression-matrices/phASER_WASP_GTEx_v8_matrix.gw_phased.txt.gz
# https://storage.googleapis.com/adult-gtex/haplotype-expression/v8/haplotype-expression-matrices/phASER_WASP_GTEx_v8_matrix.txt.gz
# https://storage.googleapis.com/adult-gtex/long-read-data/v9/long-read-RNA-seq/LORALS_GTEx_v9_ase_quant_results.gencode.txt.gz
# https://storage.googleapis.com/adult-gtex/long-read-data/v9/long-read-RNA-seq/LORALS_GTEx_v9_ase_quant_results.txt.gz
# https://storage.googleapis.com/adult-gtex/long-read-data/v9/long-read-RNA-seq/README.txt
# https://storage.googleapis.com/adult-gtex/long-read-data/v9/long-read-RNA-seq/flair_filter_transcripts.gtf.gz
# https://storage.googleapis.com/adult-gtex/long-read-data/v9/long-read-RNA-seq/quantification_flair_filter.counts.txt.gz
# https://storage.googleapis.com/adult-gtex/long-read-data/v9/long-read-RNA-seq/quantification_flair_filter.tpm.txt.gz
# https://storage.googleapis.com/adult-gtex/long-read-data/v9/long-read-RNA-seq/quantification_gencode.counts.txt.gz
# https://storage.googleapis.com/adult-gtex/long-read-data/v9/long-read-RNA-seq/quantification_gencode.tpm.txt.gz
# https://storage.googleapis.com/adult-gtex/references/v10/reference-tables/GTEx_Analysis_2021-02-11_v10_WholeGenomeSeq_953Indiv.lookup_table.txt.gz
# https://storage.googleapis.com/adult-gtex/references/v10/reference-tables/gencode.v39.GRCh38.genes.gtf
# https://storage.googleapis.com/adult-gtex/references/v3/reference-tables/GTEx_genot_imputed_variants_info4_maf05_CR95_CHR_POSb37_ID_REF_ALT.txt.zip
# https://storage.googleapis.com/adult-gtex/references/v3/reference-tables/gencode.v12.annotation.patched_contigs.gtf
# https://storage.googleapis.com/adult-gtex/references/v3/reference-tables/gencode.v12.genes.patched_contigs.exons.txt
# https://storage.googleapis.com/adult-gtex/references/v3/reference-tables/gencode.v12.genes.patched_contigs.gtf
# https://storage.googleapis.com/adult-gtex/references/v4/reference-tables/GTEx_genot_imputed_variants_info4_maf05_CR95_CHR_POSb37_ID_REF_ALT.txt.zip
# https://storage.googleapis.com/adult-gtex/references/v4/reference-tables/gencode.v18.genes.patched_contigs.gtf
# https://storage.googleapis.com/adult-gtex/references/v4/reference-tables/gencode.v18.genes.patched_contigs_exons.txt
# https://storage.googleapis.com/adult-gtex/references/v4/reference-tables/gencode.v18.transcripts.patched_contigs.gtf
# https://storage.googleapis.com/adult-gtex/references/v6/reference-tables/GTEx_Analysis_2015-01-12_OMNI_2.5M_5M_450Indiv_chr1-22-X_genot_imput_info04_maf01_HWEp1E6_variant_id_lookup.txt.gz
# https://storage.googleapis.com/adult-gtex/references/v6/reference-tables/Homo_sapiens_assembly19.fasta.gz
# https://storage.googleapis.com/adult-gtex/references/v6/reference-tables/gencode.v19.genes.patched_contigs.gtf.gz
# https://storage.googleapis.com/adult-gtex/references/v6/reference-tables/gencode.v19.genes.patched_contigs_exons.txt
# https://storage.googleapis.com/adult-gtex/references/v6/reference-tables/gencode.v19.transcripts.patched_contigs.gtf.gz
# https://storage.googleapis.com/adult-gtex/references/v6p/reference-tables/gencode.v19.genes.v6p_model.patched_contigs.gtf.gz
# https://storage.googleapis.com/adult-gtex/references/v7/reference-tables/GTEx_Analysis_2016-01-15_v7_WholeGenomeSeq_635Ind_PASS_AB02_GQ20_HETX_MISS15_PLINKQC.lookup_table.txt.gz
# https://storage.googleapis.com/adult-gtex/references/v7/reference-tables/Homo_sapiens_assembly19.fasta.gz
# https://storage.googleapis.com/adult-gtex/references/v7/reference-tables/gencode.v19.genes.v7.patched_contigs.exons.txt
# https://storage.googleapis.com/adult-gtex/references/v7/reference-tables/gencode.v19.genes.v7.patched_contigs.gtf
# https://storage.googleapis.com/adult-gtex/references/v7/reference-tables/gencode.v19.transcripts.patched_contigs.gtf
# https://storage.googleapis.com/adult-gtex/references/v8/reference-tables/GTEx_Analysis_2017-06-05_v8_WholeGenomeSeq_838Indiv_Analysis_Freeze.lookup_table.txt.gz
# https://storage.googleapis.com/adult-gtex/references/v8/reference-tables/WGS_Feature_overlap_collapsed_VEP_short_4torus.MAF01.txt.gz
# https://storage.googleapis.com/adult-gtex/references/v8/reference-tables/gencode.v26.GRCh38.genes.gtf
# https://storage.googleapis.com/adult-gtex/single-cell/v9/snrna-seq-data/GTEx_8_tissues_snRNAseq_atlas_071421.public_obs.h5ad
# https://storage.googleapis.com/adult-gtex/single-cell/v9/snrna-seq-data/GTEx_8_tissues_snRNAseq_immune_atlas_071421.public_obs.h5ad
# https://storage.googleapis.com/adult-gtex/variants/v3/ptv-data/GTEx_Pilot_LoF_mmPCR-seq_RNA-seq_INDEL_SNP_coverage8_counts.txt
# https://storage.googleapis.com/adult-gtex/variants/v3/ptv-data/GTEx_Pilot_LoF_mmPCR-seq_RNA-seq_SNPonly_coverage8_counts.txt
# https://storage.googleapis.com/adult-gtex/variants/v3/ptv-data/README.mmPCR
# https://storage.googleapis.com/adult-gtex/variants/v3/ptv-data/README.normalizedquants_ptvs
# https://storage.googleapis.com/adult-gtex/variants/v3/ptv-data/README.psiQTLs.Tables.txt
# https://storage.googleapis.com/adult-gtex/variants/v3/ptv-data/gtex_psiqtls.zip
# https://storage.googleapis.com/adult-gtex/variants/v3/ptv-data/normalizedquants_ptvs.tar.gz
# https://storage.googleapis.com/adult-gtex/variants/v6/structural-variant-data/GTEx_Analysis_2016-10-24_WholeGenomeSeq_147Indiv_SV_sites.vcf.gz
# https://storage.googleapis.com/adult-gtex/variants/v6/structural-variant-data/GTEx_Analysis_2016-10-24_WholeGenomeSeq_147Indiv_SV_sites_only_README.txt
# https://storage.googleapis.com/adult-gtex/variants/v6/structural-variant-data/README_SV_eQTL.txt
# https://storage.googleapis.com/adult-gtex/variants/v6/structural-variant-data/supp_table.02.SV_eQTL.xlsx

# %%
import os
import requests
import pandas as pd

def walk(obj):
    if isinstance(obj, dict):
        for v in obj.values():
            yield from walk(v)
    elif isinstance(obj, list):
        for item in obj:
            yield from walk(item)
    yield obj

def get_urls(project_id="adult-gtex", keyword="bulk-gex/v10"):
    url = f"https://gtexportal.org/api/v2/dataset/openAccessFilesMetadata?project_id={project_id}"
    data = requests.get(url).json()
    urls = []

    for node in walk(data):
        if isinstance(node, dict) and node.get("url"):
            if keyword in node["url"]:
                urls.append(node["url"])

    return urls

# Fetch only the 54 V10 files
urls = get_urls()

# Build DataFrame
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
df = pd.DataFrame({
    "name": [os.path.basename(u) for u in urls],
    "url": urls
})

print(df)
# Out:
#                                                                name  \
# 0                GTEx_Analysis_v10_RNASeQCv2.4.2_exon_reads.parquet
# 1            GTEx_Analysis_v10_RNASeQCv2.4.2_gene_median_tpm.gct.gz
# 2                 GTEx_Analysis_v10_RNASeQCv2.4.2_gene_reads.gct.gz
# 3                   GTEx_Analysis_v10_RNASeQCv2.4.2_gene_tpm.gct.gz
# 4               GTEx_Analysis_v10_RNASeQCv2.4.2_gene_tpm_lcm.gct.gz
# 5    GTEx_Analysis_v10_RSEMv1.3.3_transcripts_expected_count.txt.gz
# 6               GTEx_Analysis_v10_RSEMv1.3.3_transcripts_tpm.txt.gz
# 7                   GTEx_Analysis_v10_STARv2.7.10a_junctions.gct.gz
# 8                        gene_reads_v10_adipose_subcutaneous.gct.gz
# 9                    gene_reads_v10_adipose_visceral_omentum.gct.gz
# 10                              gene_reads_v10_adrenal_gland.gct.gz
# 11                               gene_reads_v10_artery_aorta.gct.gz
# 12                            gene_reads_v10_artery_coronary.gct.gz
# 13                              gene_reads_v10_artery_tibial.gct.gz
# 14                                    gene_reads_v10_bladder.gct.gz
# 15                             gene_reads_v10_brain_amygdala.gct.gz
# 16       gene_reads_v10_brain_anterior_cingulate_cortex_ba24.gct.gz
# 17                gene_reads_v10_brain_caudate_basal_ganglia.gct.gz
# 18                gene_reads_v10_brain_cerebellar_hemisphere.gct.gz
# 19                           gene_reads_v10_brain_cerebellum.gct.gz
# 20                               gene_reads_v10_brain_cortex.gct.gz
# 21                   gene_reads_v10_brain_frontal_cortex_ba9.gct.gz
# 22                          gene_reads_v10_brain_hippocampus.gct.gz
# 23                         gene_reads_v10_brain_hypothalamus.gct.gz
# 24      gene_reads_v10_brain_nucleus_accumbens_basal_ganglia.gct.gz
# 25                gene_reads_v10_brain_putamen_basal_ganglia.gct.gz
# 26             gene_reads_v10_brain_spinal_cord_cervical_c-1.gct.gz
# 27                     gene_reads_v10_brain_substantia_nigra.gct.gz
# 28                      gene_reads_v10_breast_mammary_tissue.gct.gz
# 29                 gene_reads_v10_cells_cultured_fibroblasts.gct.gz
# 30          gene_reads_v10_cells_ebv-transformed_lymphocytes.gct.gz
# 31                          gene_reads_v10_cervix_ectocervix.gct.gz
# 32                          gene_reads_v10_cervix_endocervix.gct.gz
# 33                              gene_reads_v10_colon_sigmoid.gct.gz
# 34                           gene_reads_v10_colon_transverse.gct.gz
# 35        gene_reads_v10_esophagus_gastroesophageal_junction.gct.gz
# 36                           gene_reads_v10_esophagus_mucosa.gct.gz
# 37                       gene_reads_v10_esophagus_muscularis.gct.gz
# 38                             gene_reads_v10_fallopian_tube.gct.gz
# 39                     gene_reads_v10_heart_atrial_appendage.gct.gz
# 40                       gene_reads_v10_heart_left_ventricle.gct.gz
# 41                              gene_reads_v10_kidney_cortex.gct.gz
# 42                             gene_reads_v10_kidney_medulla.gct.gz
# 43                                      gene_reads_v10_liver.gct.gz
# 44                                       gene_reads_v10_lung.gct.gz
# 45                       gene_reads_v10_minor_salivary_gland.gct.gz
# 46                            gene_reads_v10_muscle_skeletal.gct.gz
# 47                               gene_reads_v10_nerve_tibial.gct.gz
# 48                                      gene_reads_v10_ovary.gct.gz
# 49                                   gene_reads_v10_pancreas.gct.gz
# 50                                  gene_reads_v10_pituitary.gct.gz
# 51                                   gene_reads_v10_prostate.gct.gz
# 52            gene_reads_v10_skin_not_sun_exposed_suprapubic.gct.gz
# 53                 gene_reads_v10_skin_sun_exposed_lower_leg.gct.gz
# 54             gene_reads_v10_small_intestine_terminal_ileum.gct.gz
# 55                                     gene_reads_v10_spleen.gct.gz
# 56                                    gene_reads_v10_stomach.gct.gz
# 57                                     gene_reads_v10_testis.gct.gz
# 58                                    gene_reads_v10_thyroid.gct.gz
# 59                                     gene_reads_v10_uterus.gct.gz
# 60                                     gene_reads_v10_vagina.gct.gz
# 61                                gene_reads_v10_whole_blood.gct.gz
# 62                         gene_tpm_v10_adipose_subcutaneous.gct.gz
# 63                     gene_tpm_v10_adipose_visceral_omentum.gct.gz
# 64                                gene_tpm_v10_adrenal_gland.gct.gz
# 65                                 gene_tpm_v10_artery_aorta.gct.gz
# 66                              gene_tpm_v10_artery_coronary.gct.gz
# 67                                gene_tpm_v10_artery_tibial.gct.gz
# 68                                      gene_tpm_v10_bladder.gct.gz
# 69                               gene_tpm_v10_brain_amygdala.gct.gz
# 70         gene_tpm_v10_brain_anterior_cingulate_cortex_ba24.gct.gz
# 71                  gene_tpm_v10_brain_caudate_basal_ganglia.gct.gz
# 72                  gene_tpm_v10_brain_cerebellar_hemisphere.gct.gz
# 73                             gene_tpm_v10_brain_cerebellum.gct.gz
# 74                                 gene_tpm_v10_brain_cortex.gct.gz
# 75                     gene_tpm_v10_brain_frontal_cortex_ba9.gct.gz
# 76                            gene_tpm_v10_brain_hippocampus.gct.gz
# 77                           gene_tpm_v10_brain_hypothalamus.gct.gz
# 78        gene_tpm_v10_brain_nucleus_accumbens_basal_ganglia.gct.gz
# 79                  gene_tpm_v10_brain_putamen_basal_ganglia.gct.gz
# 80               gene_tpm_v10_brain_spinal_cord_cervical_c-1.gct.gz
# 81                       gene_tpm_v10_brain_substantia_nigra.gct.gz
# 82                        gene_tpm_v10_breast_mammary_tissue.gct.gz
# 83                   gene_tpm_v10_cells_cultured_fibroblasts.gct.gz
# 84            gene_tpm_v10_cells_ebv-transformed_lymphocytes.gct.gz
# 85                            gene_tpm_v10_cervix_ectocervix.gct.gz
# 86                            gene_tpm_v10_cervix_endocervix.gct.gz
# 87                                gene_tpm_v10_colon_sigmoid.gct.gz
# 88                             gene_tpm_v10_colon_transverse.gct.gz
# 89          gene_tpm_v10_esophagus_gastroesophageal_junction.gct.gz
# 90                             gene_tpm_v10_esophagus_mucosa.gct.gz
# 91                         gene_tpm_v10_esophagus_muscularis.gct.gz
# 92                               gene_tpm_v10_fallopian_tube.gct.gz
# 93                       gene_tpm_v10_heart_atrial_appendage.gct.gz
# 94                         gene_tpm_v10_heart_left_ventricle.gct.gz
# 95                                gene_tpm_v10_kidney_cortex.gct.gz
# 96                               gene_tpm_v10_kidney_medulla.gct.gz
# 97                                        gene_tpm_v10_liver.gct.gz
# 98                                         gene_tpm_v10_lung.gct.gz
# 99                         gene_tpm_v10_minor_salivary_gland.gct.gz
# 100                             gene_tpm_v10_muscle_skeletal.gct.gz
# 101                                gene_tpm_v10_nerve_tibial.gct.gz
# 102                                       gene_tpm_v10_ovary.gct.gz
# 103                                    gene_tpm_v10_pancreas.gct.gz
# 104                                   gene_tpm_v10_pituitary.gct.gz
# 105                                    gene_tpm_v10_prostate.gct.gz
# 106             gene_tpm_v10_skin_not_sun_exposed_suprapubic.gct.gz
# 107                  gene_tpm_v10_skin_sun_exposed_lower_leg.gct.gz
# 108              gene_tpm_v10_small_intestine_terminal_ileum.gct.gz
# 109                                      gene_tpm_v10_spleen.gct.gz
# 110                                     gene_tpm_v10_stomach.gct.gz
# 111                                      gene_tpm_v10_testis.gct.gz
# 112                                     gene_tpm_v10_thyroid.gct.gz
# 113                                      gene_tpm_v10_uterus.gct.gz
# 114                                      gene_tpm_v10_vagina.gct.gz
# 115                                 gene_tpm_v10_whole_blood.gct.gz
# 116         GTEx_Analysis_v10_smallRNA_gene_reads_2025_03_17.txt.gz
# 117                                                      README.pdf
# 118                       miRNA_TPM_matrix_PORTAL_2025_03_17.txt.gz
#
#                                                                                                                                              url
# 0                              https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RNASeQCv2.4.2_exon_reads.parquet
# 1                          https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_median_tpm.gct.gz
# 2                               https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_reads.gct.gz
# 3                                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_tpm.gct.gz
# 4                             https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_tpm_lcm.gct.gz
# 5                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RSEMv1.3.3_transcripts_expected_count.txt.gz
# 6                             https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_RSEMv1.3.3_transcripts_tpm.txt.gz
# 7                                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/GTEx_Analysis_v10_STARv2.7.10a_junctions.gct.gz
# 8                     https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_adipose_subcutaneous.gct.gz
# 9                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_adipose_visceral_omentum.gct.gz
# 10                           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_adrenal_gland.gct.gz
# 11                            https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_artery_aorta.gct.gz
# 12                         https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_artery_coronary.gct.gz
# 13                           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_artery_tibial.gct.gz
# 14                                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_bladder.gct.gz
# 15                          https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_amygdala.gct.gz
# 16    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_anterior_cingulate_cortex_ba24.gct.gz
# 17             https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_caudate_basal_ganglia.gct.gz
# 18             https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_cerebellar_hemisphere.gct.gz
# 19                        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_cerebellum.gct.gz
# 20                            https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_cortex.gct.gz
# 21                https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_frontal_cortex_ba9.gct.gz
# 22                       https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_hippocampus.gct.gz
# 23                      https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_hypothalamus.gct.gz
# 24   https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_nucleus_accumbens_basal_ganglia.gct.gz
# 25             https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_putamen_basal_ganglia.gct.gz
# 26          https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_spinal_cord_cervical_c-1.gct.gz
# 27                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_brain_substantia_nigra.gct.gz
# 28                   https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_breast_mammary_tissue.gct.gz
# 29              https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_cells_cultured_fibroblasts.gct.gz
# 30       https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_cells_ebv-transformed_lymphocytes.gct.gz
# 31                       https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_cervix_ectocervix.gct.gz
# 32                       https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_cervix_endocervix.gct.gz
# 33                           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_colon_sigmoid.gct.gz
# 34                        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_colon_transverse.gct.gz
# 35     https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_esophagus_gastroesophageal_junction.gct.gz
# 36                        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_esophagus_mucosa.gct.gz
# 37                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_esophagus_muscularis.gct.gz
# 38                          https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_fallopian_tube.gct.gz
# 39                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_heart_atrial_appendage.gct.gz
# 40                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_heart_left_ventricle.gct.gz
# 41                           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_kidney_cortex.gct.gz
# 42                          https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_kidney_medulla.gct.gz
# 43                                   https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_liver.gct.gz
# 44                                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_lung.gct.gz
# 45                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_minor_salivary_gland.gct.gz
# 46                         https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_muscle_skeletal.gct.gz
# 47                            https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_nerve_tibial.gct.gz
# 48                                   https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_ovary.gct.gz
# 49                                https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_pancreas.gct.gz
# 50                               https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_pituitary.gct.gz
# 51                                https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_prostate.gct.gz
# 52         https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_skin_not_sun_exposed_suprapubic.gct.gz
# 53              https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_skin_sun_exposed_lower_leg.gct.gz
# 54          https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_small_intestine_terminal_ileum.gct.gz
# 55                                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_spleen.gct.gz
# 56                                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_stomach.gct.gz
# 57                                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_testis.gct.gz
# 58                                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_thyroid.gct.gz
# 59                                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_uterus.gct.gz
# 60                                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_vagina.gct.gz
# 61                             https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/counts-by-tissue/gene_reads_v10_whole_blood.gct.gz
# 62                        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_adipose_subcutaneous.gct.gz
# 63                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_adipose_visceral_omentum.gct.gz
# 64                               https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_adrenal_gland.gct.gz
# 65                                https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_artery_aorta.gct.gz
# 66                             https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_artery_coronary.gct.gz
# 67                               https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_artery_tibial.gct.gz
# 68                                     https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_bladder.gct.gz
# 69                              https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_amygdala.gct.gz
# 70        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_anterior_cingulate_cortex_ba24.gct.gz
# 71                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_caudate_basal_ganglia.gct.gz
# 72                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_cerebellar_hemisphere.gct.gz
# 73                            https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_cerebellum.gct.gz
# 74                                https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_cortex.gct.gz
# 75                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_frontal_cortex_ba9.gct.gz
# 76                           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_hippocampus.gct.gz
# 77                          https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_hypothalamus.gct.gz
# 78       https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_nucleus_accumbens_basal_ganglia.gct.gz
# 79                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_putamen_basal_ganglia.gct.gz
# 80              https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_spinal_cord_cervical_c-1.gct.gz
# 81                      https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_substantia_nigra.gct.gz
# 82                       https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_breast_mammary_tissue.gct.gz
# 83                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_cells_cultured_fibroblasts.gct.gz
# 84           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_cells_ebv-transformed_lymphocytes.gct.gz
# 85                           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_cervix_ectocervix.gct.gz
# 86                           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_cervix_endocervix.gct.gz
# 87                               https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_colon_sigmoid.gct.gz
# 88                            https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_colon_transverse.gct.gz
# 89         https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_esophagus_gastroesophageal_junction.gct.gz
# 90                            https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_esophagus_mucosa.gct.gz
# 91                        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_esophagus_muscularis.gct.gz
# 92                              https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_fallopian_tube.gct.gz
# 93                      https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_heart_atrial_appendage.gct.gz
# 94                        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_heart_left_ventricle.gct.gz
# 95                               https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_kidney_cortex.gct.gz
# 96                              https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_kidney_medulla.gct.gz
# 97                                       https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_liver.gct.gz
# 98                                        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_lung.gct.gz
# 99                        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_minor_salivary_gland.gct.gz
# 100                            https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_muscle_skeletal.gct.gz
# 101                               https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_nerve_tibial.gct.gz
# 102                                      https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_ovary.gct.gz
# 103                                   https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_pancreas.gct.gz
# 104                                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_pituitary.gct.gz
# 105                                   https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_prostate.gct.gz
# 106            https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_skin_not_sun_exposed_suprapubic.gct.gz
# 107                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_skin_sun_exposed_lower_leg.gct.gz
# 108             https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_small_intestine_terminal_ileum.gct.gz
# 109                                     https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_spleen.gct.gz
# 110                                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_stomach.gct.gz
# 111                                     https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_testis.gct.gz
# 112                                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_thyroid.gct.gz
# 113                                     https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_uterus.gct.gz
# 114                                     https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_vagina.gct.gz
# 115                                https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_whole_blood.gct.gz
# 116                     https://storage.googleapis.com/adult-gtex/bulk-gex/v10/small-RNA/GTEx_Analysis_v10_smallRNA_gene_reads_2025_03_17.txt.gz
# 117                                                                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/small-RNA/README.pdf
# 118                                   https://storage.googleapis.com/adult-gtex/bulk-gex/v10/small-RNA/miRNA_TPM_matrix_PORTAL_2025_03_17.txt.gz

# %%
# df

# %%
df[df['name'].str.startswith("gene_tpm_v10")]
# Out:
#                                                           name  \
# 62                    gene_tpm_v10_adipose_subcutaneous.gct.gz
# 63                gene_tpm_v10_adipose_visceral_omentum.gct.gz
# 64                           gene_tpm_v10_adrenal_gland.gct.gz
# 65                            gene_tpm_v10_artery_aorta.gct.gz
# 66                         gene_tpm_v10_artery_coronary.gct.gz
# 67                           gene_tpm_v10_artery_tibial.gct.gz
# 68                                 gene_tpm_v10_bladder.gct.gz
# 69                          gene_tpm_v10_brain_amygdala.gct.gz
# 70    gene_tpm_v10_brain_anterior_cingulate_cortex_ba24.gct.gz
# 71             gene_tpm_v10_brain_caudate_basal_ganglia.gct.gz
# 72             gene_tpm_v10_brain_cerebellar_hemisphere.gct.gz
# 73                        gene_tpm_v10_brain_cerebellum.gct.gz
# 74                            gene_tpm_v10_brain_cortex.gct.gz
# 75                gene_tpm_v10_brain_frontal_cortex_ba9.gct.gz
# 76                       gene_tpm_v10_brain_hippocampus.gct.gz
# 77                      gene_tpm_v10_brain_hypothalamus.gct.gz
# 78   gene_tpm_v10_brain_nucleus_accumbens_basal_ganglia.gct.gz
# 79             gene_tpm_v10_brain_putamen_basal_ganglia.gct.gz
# 80          gene_tpm_v10_brain_spinal_cord_cervical_c-1.gct.gz
# 81                  gene_tpm_v10_brain_substantia_nigra.gct.gz
# 82                   gene_tpm_v10_breast_mammary_tissue.gct.gz
# 83              gene_tpm_v10_cells_cultured_fibroblasts.gct.gz
# 84       gene_tpm_v10_cells_ebv-transformed_lymphocytes.gct.gz
# 85                       gene_tpm_v10_cervix_ectocervix.gct.gz
# 86                       gene_tpm_v10_cervix_endocervix.gct.gz
# 87                           gene_tpm_v10_colon_sigmoid.gct.gz
# 88                        gene_tpm_v10_colon_transverse.gct.gz
# 89     gene_tpm_v10_esophagus_gastroesophageal_junction.gct.gz
# 90                        gene_tpm_v10_esophagus_mucosa.gct.gz
# 91                    gene_tpm_v10_esophagus_muscularis.gct.gz
# 92                          gene_tpm_v10_fallopian_tube.gct.gz
# 93                  gene_tpm_v10_heart_atrial_appendage.gct.gz
# 94                    gene_tpm_v10_heart_left_ventricle.gct.gz
# 95                           gene_tpm_v10_kidney_cortex.gct.gz
# 96                          gene_tpm_v10_kidney_medulla.gct.gz
# 97                                   gene_tpm_v10_liver.gct.gz
# 98                                    gene_tpm_v10_lung.gct.gz
# 99                    gene_tpm_v10_minor_salivary_gland.gct.gz
# 100                        gene_tpm_v10_muscle_skeletal.gct.gz
# 101                           gene_tpm_v10_nerve_tibial.gct.gz
# 102                                  gene_tpm_v10_ovary.gct.gz
# 103                               gene_tpm_v10_pancreas.gct.gz
# 104                              gene_tpm_v10_pituitary.gct.gz
# 105                               gene_tpm_v10_prostate.gct.gz
# 106        gene_tpm_v10_skin_not_sun_exposed_suprapubic.gct.gz
# 107             gene_tpm_v10_skin_sun_exposed_lower_leg.gct.gz
# 108         gene_tpm_v10_small_intestine_terminal_ileum.gct.gz
# 109                                 gene_tpm_v10_spleen.gct.gz
# 110                                gene_tpm_v10_stomach.gct.gz
# 111                                 gene_tpm_v10_testis.gct.gz
# 112                                gene_tpm_v10_thyroid.gct.gz
# 113                                 gene_tpm_v10_uterus.gct.gz
# 114                                 gene_tpm_v10_vagina.gct.gz
# 115                            gene_tpm_v10_whole_blood.gct.gz
#
#                                                                                                                                          url
# 62                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_adipose_subcutaneous.gct.gz
# 63                https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_adipose_visceral_omentum.gct.gz
# 64                           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_adrenal_gland.gct.gz
# 65                            https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_artery_aorta.gct.gz
# 66                         https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_artery_coronary.gct.gz
# 67                           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_artery_tibial.gct.gz
# 68                                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_bladder.gct.gz
# 69                          https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_amygdala.gct.gz
# 70    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_anterior_cingulate_cortex_ba24.gct.gz
# 71             https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_caudate_basal_ganglia.gct.gz
# 72             https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_cerebellar_hemisphere.gct.gz
# 73                        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_cerebellum.gct.gz
# 74                            https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_cortex.gct.gz
# 75                https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_frontal_cortex_ba9.gct.gz
# 76                       https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_hippocampus.gct.gz
# 77                      https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_hypothalamus.gct.gz
# 78   https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_nucleus_accumbens_basal_ganglia.gct.gz
# 79             https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_putamen_basal_ganglia.gct.gz
# 80          https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_spinal_cord_cervical_c-1.gct.gz
# 81                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_brain_substantia_nigra.gct.gz
# 82                   https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_breast_mammary_tissue.gct.gz
# 83              https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_cells_cultured_fibroblasts.gct.gz
# 84       https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_cells_ebv-transformed_lymphocytes.gct.gz
# 85                       https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_cervix_ectocervix.gct.gz
# 86                       https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_cervix_endocervix.gct.gz
# 87                           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_colon_sigmoid.gct.gz
# 88                        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_colon_transverse.gct.gz
# 89     https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_esophagus_gastroesophageal_junction.gct.gz
# 90                        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_esophagus_mucosa.gct.gz
# 91                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_esophagus_muscularis.gct.gz
# 92                          https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_fallopian_tube.gct.gz
# 93                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_heart_atrial_appendage.gct.gz
# 94                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_heart_left_ventricle.gct.gz
# 95                           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_kidney_cortex.gct.gz
# 96                          https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_kidney_medulla.gct.gz
# 97                                   https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_liver.gct.gz
# 98                                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_lung.gct.gz
# 99                    https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_minor_salivary_gland.gct.gz
# 100                        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_muscle_skeletal.gct.gz
# 101                           https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_nerve_tibial.gct.gz
# 102                                  https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_ovary.gct.gz
# 103                               https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_pancreas.gct.gz
# 104                              https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_pituitary.gct.gz
# 105                               https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_prostate.gct.gz
# 106        https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_skin_not_sun_exposed_suprapubic.gct.gz
# 107             https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_skin_sun_exposed_lower_leg.gct.gz
# 108         https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_small_intestine_terminal_ileum.gct.gz
# 109                                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_spleen.gct.gz
# 110                                https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_stomach.gct.gz
# 111                                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_testis.gct.gz
# 112                                https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_thyroid.gct.gz
# 113                                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_uterus.gct.gz
# 114                                 https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_vagina.gct.gz
# 115                            https://storage.googleapis.com/adult-gtex/bulk-gex/v10/rna-seq/tpms-by-tissue/gene_tpm_v10_whole_blood.gct.gz

# %%
len(df[df['name'].str.startswith("gene_tpm_v10")]) # 54 entries as shown on the website
# Out:
# 54

# %%
# TODO: make a user input interface

# %%
tpm_df = df[df['name'].str.startswith("gene_tpm_v10")].copy()
tpm_df['tissue'] = tpm_df['name'].str.replace('gene_tpm_v10_', '').str.replace('.gct.gz', '')
tissues = tpm_df['tissue'].tolist()
print(f"Available tissues ({len(tissues)}):")
print(tissues)
# Out:
# Available tissues (54):
# ['adipose_subcutaneous', 'adipose_visceral_omentum', 'adrenal_gland', 'artery_aorta', 'artery_coronary', 'artery_tibial', 'bladder', 'brain_amygdala', 'brain_anterior_cingulate_cortex_ba24', 'brain_caudate_basal_ganglia', 'brain_cerebellar_hemisphere', 'brain_cerebellum', 'brain_cortex', 'brain_frontal_cortex_ba9', 'brain_hippocampus', 'brain_hypothalamus', 'brain_nucleus_accumbens_basal_ganglia', 'brain_putamen_basal_ganglia', 'brain_spinal_cord_cervical_c-1', 'brain_substantia_nigra', 'breast_mammary_tissue', 'cells_cultured_fibroblasts', 'cells_ebv-transformed_lymphocytes', 'cervix_ectocervix', 'cervix_endocervix', 'colon_sigmoid', 'colon_transverse', 'esophagus_gastroesophageal_junction', 'esophagus_mucosa', 'esophagus_muscularis', 'fallopian_tube', 'heart_atrial_appendage', 'heart_left_ventricle', 'kidney_cortex', 'kidney_medulla', 'liver', 'lung', 'minor_salivary_gland', 'muscle_skeletal', 'nerve_tibial', 'ovary', 'pancreas', 'pituitary', 'prostate', 'skin_not_sun_exposed_suprapubic', 'skin_sun_exposed_lower_leg', 'small_intestine_terminal_ileum', 'spleen', 'stomach', 'testis', 'thyroid', 'uterus', 'vagina', 'whole_blood']

# %%
# tpm_df.loc[tpm_df["tissue"] == "bladder", "url"]

# %%
import aiohttp
import asyncio
from aiohttp import ClientTimeout
import pandas as pd
import os
from rich import print
from rich.console import Console
from rich.table import Table
import yaml
from rich.progress import (
    Progress, BarColumn, TimeElapsedColumn,
    TimeRemainingColumn, DownloadColumn, TransferSpeedColumn
)
import sys
import logging
from pathlib import Path
from pythonjsonlogger import jsonlogger
import time

# %%
# log template ## betterstack.com
logger = logging.getLogger(__name__)
# addition ## ensure log dir exists # TODO: Switch to a single logging file instead
log_path = Path("data/data_raw/hca_api_logs.txt")
log_path.parent.mkdir(parents=True, exist_ok=True)

stdoutHandler = logging.StreamHandler(stream=sys.stdout)
fileHandler = logging.FileHandler(log_path)

jsonFmt = jsonlogger.JsonFormatter(
    "%(name)s %(asctime)s %(levelname)s %(filename)s %(lineno)s %(process)d %(message)s",
    rename_fields={"levelname": "severity", "asctime": "timestamp"},
    datefmt="%Y-%m-%dT%H:%M:%SZ",
)

stdoutHandler.setFormatter(jsonFmt)
fileHandler.setFormatter(jsonFmt)

logger.addHandler(stdoutHandler)
logger.addHandler(fileHandler)

logger.setLevel(logging.DEBUG)

from aiohttp import ClientTimeout
timeout = ClientTimeout(total=None)
headers = {"User-Agent": "Mozilla/5.0"}

# %%
# download func; In 1 mb chunks
async def download_file(url, filename, chunk_size=1024*1024, retries=3):

    for i in range(retries):
        try:
            connector = aiohttp.TCPConnector(limit=10)
            async with aiohttp.ClientSession(timeout=timeout, headers=headers, connector=connector) as session:
                async with session.get(url) as response:

                    if response.status != 200:
                        logger.error("HTTP error", extra={"status": response.status, "url": url})
                        raise Exception(f"Failed: {response.status}")
                    
                    total = response.content_length

                    with Progress(
                        "[progress.description]{task.description}",
                        DownloadColumn(),
                        BarColumn(),
                        TransferSpeedColumn(),
                        TimeRemainingColumn(),
                        TimeElapsedColumn(),
                    ) as progress:

                        task = progress.add_task(
                            f"Downloading {os.path.basename(filename)}",
                            total=total
                        )

                        with open(filename, "wb") as f:
                            async for chunk in response.content.iter_chunked(chunk_size):
                                try:
                                    f.write(chunk)
                                    #raise RuntimeError("test")
                                    progress.update(task, advance=len(chunk))
                                except Exception:
                                    logger.critical("failed to write chunks while downloading", exc_info=True)
                                    raise

## When the download fails (after retries the branch/pipeline) still continues. #TODO: think if this needs fixn

            print("Download complete:", filename)
            return

        except Exception as e:
            print(f"Retry {i+1} failed:", e)
            time.sleep(2 ** i)

# %%
from pathlib import Path

async def download_tissue(tissue_name, output_path="."):
    row = tpm_df.loc[tpm_df["tissue"] == tissue_name]

    if row.empty:
        print(f"Tissue '{tissue_name}' not found")
        return None

    url = row["url"].iloc[0]
    filename = row["name"].iloc[0]

    output_path = Path(output_path)
    output_path.mkdir(parents=True, exist_ok=True)

    out_file = output_path / filename

    await download_file(url, str(out_file))

    return str(out_file)

# %%
await download_tissue("liver")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Download complete: gene_tpm_v10_liver.gct.gz
# 'gene_tpm_v10_liver.gct.gz'
